# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread('P_00004.png')
plt.figure(figsize=(12,8))
plt.imshow(img1);

# %%
img2 = cv2.imread('P_00005.png')
plt.figure(figsize=(12,8))
plt.imshow(img2);

# %%
img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2_gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(12,8))
plt.imshow(img1_gray,cmap='gray')

# %%
plt.figure(figsize=(12,8))
plt.imshow(img2_gray,cmap='gray')

# %%
hist,bins = np.histogram(img1_gray.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img1.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
hist,bins = np.histogram(img2_gray.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img1.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
img1_equ = cv2.equalizeHist(img1_gray)
plt.figure(figsize=(12,8))
plt.imshow(img1_equ,cmap='gray');

# %%
hist,bins = np.histogram(img1_equ.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img1_equ.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
img2_equ = cv2.equalizeHist(img2_gray)
plt.figure(figsize=(12,8))
plt.imshow(img2_equ,cmap='gray');

# %%
hist,bins = np.histogram(img2_equ.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img1_equ.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
#Median Blur

img1_blur = cv2.medianBlur(img1_equ,9) 
plt.figure(figsize=(12,8))
plt.imshow(img1_blur,cmap='gray')

# %%
img2_blur = cv2.medianBlur(img2_equ,9) 
plt.figure(figsize=(12,8))
plt.imshow(img2_blur,cmap='gray')

# %%
#Gaussian Blur

img1_Gblur = cv2.GaussianBlur(img1_equ,(3,3),0)
plt.figure(figsize=(12,8))
plt.imshow(img1_Gblur,cmap='gray')

# %%
img2_Gblur = cv2.GaussianBlur(img2_equ,(3,3),0)
plt.figure(figsize=(12,8))
plt.imshow(img2_Gblur,cmap='gray')

# %%
#Using Bilateral Filter

img1_Bblur = cv2.bilateralFilter(img1_equ,9,75,75)
plt.figure(figsize=(12,8))
plt.imshow(img1_Bblur,cmap='gray')

# %%
#Using Bilateral Filter

img2_Bblur = cv2.bilateralFilter(img2_equ,9,75,75)
plt.figure(figsize=(12,8))
plt.imshow(img2_Bblur,cmap='gray')

# %%
#Before and After Smoothing (Blur)

plt.figure(figsize=(18,10))
plt.subplot(2,2,1), plt.imshow(img1_equ,cmap = 'gray')
plt.title('Equalized Image'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(img1_blur,cmap = 'gray')
plt.title('Median Blur'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3), plt.imshow(img1_Gblur,cmap = 'gray')
plt.title('Gaussian Blur'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4), plt.imshow(img1_Bblur,cmap = 'gray')
plt.title('Bilateral Filter'), plt.xticks([]), plt.yticks([]);

# %%
plt.figure(figsize=(18,10))
plt.subplot(2,2,1), plt.imshow(img2_equ,cmap = 'gray')
plt.title('Equalized Image'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(img2_blur,cmap = 'gray')
plt.title('Median Blur'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3), plt.imshow(img2_Gblur,cmap = 'gray')
plt.title('Gaussian Blur'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4), plt.imshow(img2_Bblur,cmap = 'gray')
plt.title('Bilateral Filter'), plt.xticks([]), plt.yticks([]);

# %%
#Edge detection kernels

#Laplacian 

img1_lap = cv2.Laplacian(img1_blur,cv2.CV_8U,-1) # -1 ---> depth of output img
plt.figure(figsize=(18,8))
plt.imshow(img1_lap,cmap='gray')

# %%
# Using a binary threshold function
#Median Blur

_, img1_thresh1 = cv2.threshold(img1_blur, 120, 255, cv2.THRESH_BINARY_INV)
plt.figure(figsize=(18,8))
plt.imshow(img1_thresh1,cmap='gray')

# %%
img1_Lap1 = cv2.Laplacian(img1_thresh1,cv2.CV_8U,-1) # -1 ---> depth of output img
plt.figure(figsize=(18,8))
plt.imshow(img1_Lap1,cmap='gray')

# %%
# Using a binary threshold function 
#Gaussian blur

_, img1_thresh2 = cv2.threshold(img1_Gblur, 120, 255, cv2.THRESH_BINARY_INV)
plt.figure(figsize=(18,8))
plt.imshow(img1_thresh2,cmap='gray')

# %%
img1_Lap2 = cv2.Laplacian(img1_thresh2,cv2.CV_8U,-1) # -1 ---> depth of output img
plt.figure(figsize=(18,8))
plt.imshow(img1_Lap2,cmap='gray')

# %%
# Using a binary threshold function
#Bilateral filter

_, img1_thresh3 = cv2.threshold(img1_Bblur, 120, 255, cv2.THRESH_BINARY_INV)
plt.figure(figsize=(18,8))
plt.imshow(img1_thresh3,cmap='gray')

# %%
img1_Lap3 = cv2.Laplacian(img1_thresh3,cv2.CV_8U,-1) # -1 ---> depth of output img
plt.figure(figsize=(18,8))
plt.imshow(img1_Lap3,cmap='gray')

# %%
#Edge detection kernels

#Laplacian 

img2_lap = cv2.Laplacian(img2_blur,cv2.CV_8U,-1) # -1 ---> depth of output img
plt.figure(figsize=(18,8))
plt.imshow(img2_lap,cmap='gray')

# %%
# Using a binary threshold function
#Median Blur

_, img2_thresh1 = cv2.threshold(img2_blur, 120, 255, cv2.THRESH_BINARY_INV)
plt.figure(figsize=(18,8))
plt.imshow(img2_thresh1,cmap='gray')

# %%
img2_Lap1 = cv2.Laplacian(img2_thresh1,cv2.CV_8U,-1) # -1 ---> depth of output img
plt.figure(figsize=(18,8))
plt.imshow(img2_Lap1,cmap='gray')

# %%
# Using a binary threshold function 
#Gaussian blur

_, img2_thresh2 = cv2.threshold(img2_Gblur, 120, 255, cv2.THRESH_BINARY_INV)
plt.figure(figsize=(18,8))
plt.imshow(img2_thresh2,cmap='gray')

# %%
img2_Lap2 = cv2.Laplacian(img2_thresh2,cv2.CV_8U,-1) # -1 ---> depth of output img
plt.figure(figsize=(18,8))
plt.imshow(img2_Lap2,cmap='gray')

# %%
# Using a binary threshold function
#Bilateral filter

_, img2_thresh3 = cv2.threshold(img2_Bblur, 120, 255, cv2.THRESH_BINARY_INV)
plt.figure(figsize=(18,8))
plt.imshow(img2_thresh3,cmap='gray')

# %%
img2_Lap3 = cv2.Laplacian(img2_thresh3,cv2.CV_8U,-1) # -1 ---> depth of output img
plt.figure(figsize=(18,8))
plt.imshow(img2_Lap3,cmap='gray')

# %%
#Sobel filter using median blurred image as source

img1_sobelx1 = cv2.Sobel(img1_blur,cv2.CV_16S,1,0,ksize=3)  # x - horizontal
img1_sobelx1_16S = np.absolute(img1_sobelx1)
img1_sobelx1_8U = np.uint8(img1_sobelx1_16S)

plt.figure(figsize=(12,8))
plt.imshow(img1_sobelx1_8U,cmap='gray')

# %%
img1_sobely1 = cv2.Sobel(img1_blur,cv2.CV_16S,0,1,ksize=3)  # y - vertical
img1_sobely1_16S = np.absolute(img1_sobely1)
img1_sobely1_8U = np.uint8(img1_sobely1_16S)

plt.figure(figsize=(12,8))
plt.imshow(img1_sobely1_8U,cmap='gray')

# %%
img1_sobel_xy1 = np.sqrt(img1_sobely1**2 + img1_sobelx1**2)
plt.figure(figsize=(12,8))
plt.imshow(img1_sobel_xy1,cmap='gray')
# Out:
# <ipython-input-37-f8d7765fca8d>:1: RuntimeWarning: invalid value encountered in sqrt
#   img1_sobel_xy1 = np.sqrt(img1_sobely1**2 + img1_sobelx1**2)

# %%
#Sobel filter using Gaussian blurred image as source

img1_sobelx2 = cv2.Sobel(img1_Gblur,cv2.CV_16S,1,0,ksize=3)  # x - horizontal
img1_sobelx2_16S = np.absolute(img1_sobelx2)
img1_sobelx2_8U = np.uint8(img1_sobelx2_16S)

plt.figure(figsize=(12,8))
plt.imshow(img1_sobelx2_8U,cmap='gray')

# %%
#Sobel filter using Gaussian blurred image as source

img1_sobely2 = cv2.Sobel(img1_Gblur,cv2.CV_16S,0,1,ksize=3)  # y - vertical
img1_sobely2_16S = np.absolute(img1_sobely2)
img1_sobely2_8U = np.uint8(img1_sobely2_16S)

plt.figure(figsize=(12,8))
plt.imshow(img1_sobely2_8U,cmap='gray')

# %%
img1_sobel_xy2 = np.sqrt(img1_sobely2**2 + img1_sobelx2**2)
plt.figure(figsize=(12,8))
plt.imshow(img1_sobel_xy2,cmap='gray')
# Out:
# <ipython-input-40-1a65e240450a>:1: RuntimeWarning: invalid value encountered in sqrt
#   img1_sobel_xy2 = np.sqrt(img1_sobely2**2 + img1_sobelx2**2)

# %%
#Sobel filter using Bilateral blurred image as source

img1_sobelx3 = cv2.Sobel(img1_Bblur,cv2.CV_16S,1,0,ksize=3)  # x - horizontal
img1_sobelx3_16S = np.absolute(img1_sobelx3)
img1_sobelx3_8U = np.uint8(img1_sobelx3_16S)

plt.figure(figsize=(12,8))
plt.imshow(img1_sobelx3_8U,cmap='gray')

# %%
#Sobel filter using Bilateral blurred image as source

img1_sobely3 = cv2.Sobel(img1_Bblur,cv2.CV_16S,0,1,ksize=3)  # y - vertical
img1_sobely3_16S = np.absolute(img1_sobely3)
img1_sobely3_8U = np.uint8(img1_sobely3_16S)

plt.figure(figsize=(12,8))
plt.imshow(img1_sobely3_8U,cmap='gray')

# %%
img1_sobel_xy3 = np.sqrt(img1_sobely3**2 + img1_sobelx3**2)
plt.figure(figsize=(12,8))
plt.imshow(img1_sobel_xy3,cmap='gray')
# Out:
# <ipython-input-43-9aa5d643c856>:1: RuntimeWarning: invalid value encountered in sqrt
#   img1_sobel_xy3 = np.sqrt(img1_sobely3**2 + img1_sobelx3**2)

# %%
#Sobel filter using Gaussian blurred image as source

img2_sobelx2 = cv2.Sobel(img2_Gblur,cv2.CV_16S,1,0,ksize=3)  # x - horizontal
img2_sobelx2_16S = np.absolute(img2_sobelx2)
img2_sobelx2_8U = np.uint8(img2_sobelx2_16S)

plt.figure(figsize=(12,8))
plt.imshow(img2_sobelx2_8U,cmap='gray')

# %%
#Sobel filter using Gaussian blurred image as source

img2_sobely2 = cv2.Sobel(img2_Gblur,cv2.CV_16S,0,1,ksize=3)  # y - vertical
img2_sobely2_16S = np.absolute(img2_sobely2)
img2_sobely2_8U = np.uint8(img2_sobely2_16S)

plt.figure(figsize=(12,8))
plt.imshow(img2_sobely2_8U,cmap='gray')

# %%
img2_sobel_xy2 = np.sqrt(img2_sobely2**2 + img2_sobelx2**2)
plt.figure(figsize=(12,8))
plt.imshow(img2_sobel_xy2,cmap='gray')
# Out:
# <ipython-input-46-750adc75881e>:1: RuntimeWarning: invalid value encountered in sqrt
#   img2_sobel_xy2 = np.sqrt(img2_sobely2**2 + img2_sobelx2**2)

# %%
#Canny filter using Gaussian blurred image

img1_Canny1 = cv2.Canny(img1_Gblur,20,75)  # lower and upper bounds ---> < lower bound = not an edge, > upper bound = edge
plt.figure(figsize=(12,8))
plt.imshow(img1_Canny1,cmap='gray')

# %%
#Canny filter using Median blurred image

img1_Canny1 = cv2.Canny(img1_blur,20,75)  # lower and upper bounds ---> < lower bound = not an edge, > upper bound = edge
plt.figure(figsize=(12,8))
plt.imshow(img1_Canny1,cmap='gray')

# %%
#Canny filter using Bilateral blurred image

img1_Canny1 = cv2.Canny(img1_Bblur,20,75)  # lower and upper bounds ---> < lower bound = not an edge, > upper bound = edge
plt.figure(figsize=(12,8))
plt.imshow(img1_Canny1,cmap='gray')

# %%
img1_sobell_xy1 = np.uint8(img1_sobel_xy1)

# %%
img1_Cannyy = cv2.Canny(img1_sobell_xy1,20,75)  # lower and upper bounds ---> < lower bound = not an edge, > upper bound = edge
plt.figure(figsize=(12,8))
plt.imshow(img1_Cannyy,cmap='gray')

# %%
# Comparing PSNR values of the various outputs

from math import log10, sqrt


  
def PSNR(original, laplacian):
    mse1 = np.mean((original - laplacian) ** 2)
    if(mse1 == 0):  # MSE is zero means no noise is present in the signal 
                  
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse1))
    return psnr

def PSNR(original, canny_and_sobel):
    mse2 = np.mean((original - canny_and_sobel) ** 2)
    if(mse2 == 0):  # MSE is zero means no noise is present in the signal 
                  
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse2))
    return psnr

def PSNR(original, canny):
    mse3 = np.mean((original - canny) ** 2)
    if(mse3 == 0):  # MSE is zero means no noise is present in the signal 
                  
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse3))
    return psnr
  
def main():
     original = img1_gray
     laplacian = img1_Lap2
     value1 = PSNR(original, laplacian)
     canny_and_sobel = img1_Cannyy
     value2 = PSNR(original, canny_and_sobel)
     canny = img1_Canny1
     value3 = PSNR(original, canny)
     print(f"PSNR value of Laplacian is {value1} dB")
     
     print(f"PSNR value is {value2} dB")
     
     print(f"PSNR value is {value3} dB")  
    
if __name__ == "__main__":
    main()
# Out:
# PSNR value of Laplacian is 31.699853423492854 dB
# PSNR value is 31.698897748494144 dB
# PSNR value is 31.67877510759402 dB

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
imgP = cv2.imread('P_00004.png')
plt.figure(figsize=(12,8))
plt.imshow(imgP);

# %%
imgP_gray = cv2.cvtColor(imgP, cv2.COLOR_BGR2GRAY)

# %%
hist,bins = np.histogram(imgP_gray.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(imgP.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
imgP_equ = cv2.equalizeHist(imgP_gray)
plt.figure(figsize=(12,8))
plt.imshow(imgP_equ,cmap='gray');

# %%
hist,bins = np.histogram(imgP_equ.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(imgP_equ.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
#Median Blur

imgP_blur = cv2.medianBlur(imgP_equ,9) 
plt.figure(figsize=(12,8))
plt.imshow(imgP_blur,cmap='gray')

# %%
kernelx = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
kernely = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
img_prewittx = cv2.filter2D(imgP_blur, -1, kernelx)
img_prewitty = cv2.filter2D(imgP_blur, -1, kernely)

#cv2.imshow("Prewitt X", img_prewittx)
#cv2.imshow("Prewitt Y", img_prewitty)
#cv2.imshow("Prewitt", img_prewittx + img_prewitty)

# %%
plt.figure(figsize=(12,8))
plt.imshow(img_prewittx, cmap='gray')

# %%
plt.figure(figsize=(12,8))
plt.imshow( img_prewitty, cmap='gray')

# %%
plt.figure(figsize=(12,8))
plt.imshow(img_prewittx + img_prewitty,cmap='gray')

# %%
from scipy import ndimage
  
roberts_cross_v = np.array( [[1, 0 ],
                             [0,-1 ]] )
  
roberts_cross_h = np.array( [[ 0, 1 ],
                             [ -1, 0 ]] )

# %%
imgR = cv2.imread('P_00004.png')

vertical = ndimage.convolve( imgR, roberts_cross_v )
horizontal = ndimage.convolve( imgR, roberts_cross_h )
  
edged_img = np.sqrt( np.square(horizontal) + np.square(vertical))



plt.figure(figsize=(12,8))
plt.imshow(edged_img,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-25-6b12755bad90> in <module>
#       1 imgR = cv2.imread('P_00004.png')
#       2
# ----> 3 vertical = ndimage.convolve( imgR, roberts_cross_v )
#       4 horizontal = ndimage.convolve( imgR, roberts_cross_h )
#       5
#
# ~\Anaconda3\lib\site-packages\scipy\ndimage\filters.py in convolve(input, weights, output, mode, cval, origin)
#     753     """
#     754     return _correlate_or_convolve(input, weights, output, mode, cval,
# --> 755                                   origin, True)
#     756
#     757
#
# ~\Anaconda3\lib\site-packages\scipy\ndimage\filters.py in _correlate_or_convolve(input, weights, output, mode, cval, origin, convolution)
#     603     wshape = [ii for ii in weights.shape if ii > 0]
#     604     if len(wshape) != input.ndim:
# ...
