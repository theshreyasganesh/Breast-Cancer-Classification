# %%
import os 
os.environ['TF_KERAS'] = '1'
# %env TF_KERAS = 1
from tensorflow.keras.losses import CategoricalCrossentropy, BinaryCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy, BinaryAccuracy
from tensorflow.keras.optimizers import Adam
from tensorflow.python.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import random

from imutils import paths
import numpy as np
import pandas as pd
import skimage as sk
import skimage.transform
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
import json

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import accuracy_score, auc, classification_report, confusion_matrix, roc_curve
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
import ssl

from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Concatenate, Dense, Dropout, Flatten, Input
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
# Out:
# env: TF_KERAS=1

# %%
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf




def show_raw_image(img) -> None:
    """
    Displays a PIL image.
    :param img: the image in PIL format (before being converted to an array).
    :return: None.
    """
    img.show()




def create_label_encoder():
   
    return LabelEncoder()

# %%
# Constants
RANDOM_SEED = 111
VGG_IMG_SIZE = {
    "HEIGHT": 512,
    "WIDTH": 512
}
VGG_IMG_SIZE_LARGE = {
    "HEIGHT": 2048,
    "WIDTH": 2048
}
BATCH_SIZE = 2
EPOCH_1 = 150
EPOCH_2 = 50

# Variables set by command line arguments/flags
dataset = "mini-MIAS"   # The dataset to use.
model = "advanced"         # The model to use.
run_mode = "training"   # The type of running mode, either training or testing.
verbose_mode = False    # Boolean used to print additional logs for debugging purposes.
imagesize = "small"

# %%
def preprocess_image(image_path: str) -> np.ndarray:
 
    image = load_img(image_path,
                     color_mode="grayscale",
                     target_size=(VGG_IMG_SIZE['HEIGHT'], VGG_IMG_SIZE["WIDTH"]))
    image = img_to_array(image)
    image /= 255.0
    return image

def encode_labels(labels_list: np.ndarray, label_encoder) -> np.ndarray:
  
    labels = label_encoder.fit_transform(labels_list)
    if label_encoder.classes_.size == 2:
        return labels
    else:
        return to_categorical(labels)

def dataset_stratified_split(split: float, dataset: np.ndarray, labels: np.ndarray) -> \
        (np.ndarray, np.ndarray, np.ndarray, np.ndarray):
    
    train_X, test_X, train_Y, test_Y = train_test_split(dataset,
                                                        labels,
                                                        test_size=split,
                                                        stratify=labels,
                                                        random_state=RANDOM_SEED,
                                                        shuffle=True)
    return train_X, test_X, train_Y, test_Y


def random_rotation(image_array: np.ndarray):
    """
    Randomly rotate the image
    :param image_array: input image
    :return: randomly rotated image
    """
    random_degree = random.uniform(-20, 20)
    return sk.transform.rotate(image_array, random_degree)


def random_noise(image_array: np.ndarray):
    """
    Add random noise to image
    :param image_array: input image
    :return: image with added random noise
    """
    return sk.util.random_noise(image_array)


def horizontal_flip(image_array: np.ndarray):
    """
    Flip image
    :param image_array: input image
    :return: horizantally flipped image
    """
    return image_array[:, ::-1]




def create_individual_transform(image: np.array, transforms: dict):
    """
    Create transformation of an individual image
    :param image: input image
    :param transforms: the possible transforms to do on the image
    :return: transformed image
    """
    num_transformations_to_apply = random.randint(1, len(transforms))
    num_transforms = 0
    transformed_image = None
    while num_transforms <= num_transformations_to_apply:
        key = random.choice(list(transforms))
        transformed_image = transforms[key](image)
        num_transforms += 1

    return transformed_image


def get_class_balances(y_vals):
    """
    Count occurrences of each class.
    :param y_vals: labels
    :return: array count of each class
    """
    num_classes = len(y_vals[0])
    counts = np.zeros(num_classes)
    for y_val in y_vals:
        for i in range(num_classes):
            counts[i] += y_val[i]

    return (counts.tolist())



def import_minimias_dataset(data_dir: str, label_encoder) -> (np.ndarray, np.ndarray):
    """
    Import the dataset by pre-processing the images and encoding the labels.
    :param data_dir: Directory to the mini-MIAS images.
    :param label_encoder: The label encoder.
    :return: Two NumPy arrays, one for the processed images and one for the encoded labels.
    """
    # Initialise variables.
    images = list()
    labels = list()

    for image_path in list(paths.list_images(data_dir)):
        images.append(preprocess_image(image_path))
        labels.append(image_path.split(os.path.sep)[-2])  # Extract label from path.

    images = np.array(images, dtype="float32")  # Convert images to a batch.
    labels = np.array(labels)

    # Encode labels.
    labels = encode_labels(labels, label_encoder)

    return images, labels

# %%
def generate_image_transforms(images, labels):
    """
    oversample data by tranforming existing images
    :param images: input images
    :param labels: input labels
    :return: updated list of images and labels with extra transformed images and labels
    """
    images_with_transforms = images
    labels_with_transforms = labels

    available_transforms = {'rotate': random_rotation,
                            'noise': random_noise,
                            'horizontal_flip': horizontal_flip}

    class_balance = get_class_balances(labels)
    max_count = max(class_balance)
    to_add = [max_count - i for i in class_balance]

    for i in range(len(to_add)):
        if int(to_add[i]) == 0:
            continue
        label = np.zeros(len(to_add))
        label[i] = 1
        indices = [j for j, x in enumerate(labels) if np.array_equal(x, label)]
        indiv_class_images = [images[j] for j in indices]

        for k in range(int(to_add[i])):
            a = create_individual_transform(indiv_class_images[k % len(indiv_class_images)], available_transforms)
            transformed_image = create_individual_transform(indiv_class_images[k % len(indiv_class_images)],
                                                            available_transforms)
            transformed_image = transformed_image.reshape(1, VGG_IMG_SIZE['HEIGHT'],
                                                          VGG_IMG_SIZE['WIDTH'], 1)

            images_with_transforms = np.append(images_with_transforms, transformed_image, axis=0)
            transformed_label = label.reshape(1, len(label))
            labels_with_transforms = np.append(labels_with_transforms, transformed_label, axis=0)

    return images_with_transforms, labels_with_transforms

# %%
l_e = create_label_encoder()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
images, labels = import_minimias_dataset(data_dir="/content/drive/MyDrive/Pec_removed_mini_mias".format("mini-MIAS"),
                                                     label_encoder=l_e)

# %%
X_train, X_test, y_train, y_test = dataset_stratified_split(split=0.20, dataset=images, labels=labels)
X_train_rebalanced, y_train_rebalanced = generate_image_transforms(X_train, y_train)
X_train, X_val, y_train, y_val = dataset_stratified_split(split=0.25, dataset=X_train_rebalanced,
                                                                      labels=y_train_rebalanced)

# %%
y_ = np.concatenate((y_train, y_val))

# %%
classes_2=[]
for arr in y_:
  if(np.array_equal(arr,np.array([1,0,0]))):
    classes_2.append('BENIGN')
  elif(np.array_equal(arr, np.array([0,1,0]))):
    classes_2.append('MALIGNANT')
  else:
    classes_2.append('NORMAL')

# %%
classes_2=pd.DataFrame(classes_2)
classes_2[0].value_counts()[:20].plot(kind='barh')

# %%
classes_2[0].value_counts()
# Out:
# BENIGN       136
# MALIGNANT    136
# NORMAL       136
# Name: 0, dtype: int64

# %%
import ssl

from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Concatenate, Dense, Dropout, Flatten, Input
from tensorflow.python.keras import Sequential


# Needed to download pre-trained weights for ImageNet
ssl._create_default_https_context = ssl._create_unverified_context


def create_densenet121_model(num_classes: int):
    """
    Function to create a DenseNet121 model pre-trained with custom FC Layers.
    If the "advanced" command line argument is selected, adds an extra convolutional layer with extra filters to support
    larger images.
    :param num_classes: The number of classes (labels).
    :return: The DenseNet121 model.
    """
    # Reconfigure single channel input into a greyscale 3 channel input
    img_input = Input(shape=(512, 512, 1))
    img_conc = Concatenate()([img_input, img_input, img_input])

    # Generate a DenseNet121 model with pre-trained ImageNet weights, input as given above, excluded fully connected layers.
    model_base = DenseNet121(include_top=False, weights="imagenet", input_tensor=img_conc)

    # Add fully connected layers
    model = Sequential()
    # Start with base model consisting of convolutional layers
    model.add(model_base)

    # Flatten layer to convert each input into a 1D array (no parameters in this layer, just simple pre-processing).
    model.add(Flatten())

    fully_connected = Sequential(name="Fully_Connected")
    # Fully connected layers.
    fully_connected.add(Dropout(0.2, seed=RANDOM_SEED, name="Dropout_1"))
    fully_connected.add(Dense(units=512, activation='relu', name='Dense_1'))
    # fully_connected.add(Dropout(0.2, name="Dropout_2"))
    fully_connected.add(Dense(units=32, activation='relu', name='Dense_2'))

    # Final output layer that uses softmax activation function (because the classes are exclusive).
    if num_classes == 2:
        fully_connected.add(Dense(1, activation='sigmoid', kernel_initializer="random_uniform", name='Output'))
    else:
        fully_connected.add(
            Dense(num_classes, activation='softmax', kernel_initializer="random_uniform", name='Output'))

    model.add(fully_connected)

    # Print model details if running in debug mode.

    return model

# %%
model =create_densenet121_model(l_e.classes_.size)

# %%
    # Freeze VGG19 pre-trained layers.
   
model.layers[0].trainable = False

    # Train model with frozen layers (all training with early stopping dictated by loss in validation over 3 runs).


model.compile(optimizer='adam',loss=CategoricalCrossentropy(),metrics=[CategoricalAccuracy()])
hist = model.fit(X_train,
                 y_train,
                 validation_data=(X_val, y_val),

                 epochs=100,
                 batch_size=64,
                 )
# Out:
# Epoch 1/100
# 5/5 [==============================] - 15s 2s/step - loss: 8.7035 - categorical_accuracy: 0.3332 - val_loss: 3.9061 - val_categorical_accuracy: 0.3355
# Epoch 2/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.1683 - categorical_accuracy: 0.3760 - val_loss: 1.8786 - val_categorical_accuracy: 0.4134
# Epoch 3/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.0156 - categorical_accuracy: 0.4601 - val_loss: 1.7265 - val_categorical_accuracy: 0.4730
# Epoch 4/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.5705 - categorical_accuracy: 0.5160 - val_loss: 1.0794 - val_categorical_accuracy: 0.5353
# Epoch 5/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.5306 - categorical_accuracy: 0.5656 - val_loss: 1.9500 - val_categorical_accuracy: 0.5720
# Epoch 6/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.2047 - categorical_accuracy: 0.5975 - val_loss: 0.9146 - val_categorical_accuracy: 0.6120
# Epoch 7/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.1256 - categorical_accuracy: 0.6353 - val_loss: 1.3175 - val_categorical_accuracy: 0.6463
# Epoch 8/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0583 - categorical_accuracy: 0.6672 - val_loss: 1.2144 - val_categorical_accuracy: 0.6764
# Epoch 9/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0131 - categorical_accuracy: 0.6937 - val_loss: 0.8158 - val_categorical_accuracy: 0.7028
# Epoch 10/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0276 - categorical_accuracy: 0.7169 - val_loss: 0.8177 - val_categorical_accuracy: 0.7238
# Epoch 11/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0117 - categorical_accuracy: 0.7354 - val_loss: 1.0496 - val_categorical_accuracy: 0.7405
# Epoch 12/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0081 - categorical_accuracy: 0.7506 - val_loss: 1.2457 - val_categorical_accuracy: 0.7539
# Epoch 13/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0071 - categorical_accuracy: 0.7626 - val_loss: 1.0875 - val_categorical_accuracy: 0.7657
# Epoch 14/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0037 - categorical_accuracy: 0.7733 - val_loss: 0.8991 - val_categorical_accuracy: 0.7751
# Epoch 15/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0026 - categorical_accuracy: 0.7817 - val_loss: 0.8098 - val_categorical_accuracy: 0.7836
# Epoch 16/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0036 - categorical_accuracy: 0.7896 - val_loss: 0.7981 - val_categorical_accuracy: 0.7918
# Epoch 17/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0022 - categorical_accuracy: 0.7974 - val_loss: 0.7906 - val_categorical_accuracy: 0.7993
# Epoch 18/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0026 - categorical_accuracy: 0.8043 - val_loss: 0.7801 - val_categorical_accuracy: 0.8060
# Epoch 19/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0024 - categorical_accuracy: 0.8107 - val_loss: 0.7793 - val_categorical_accuracy: 0.8120
# Epoch 20/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0018 - categorical_accuracy: 0.8163 - val_loss: 0.7974 - val_categorical_accuracy: 0.8168
# Epoch 21/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0017 - categorical_accuracy: 0.8206 - val_loss: 0.8389 - val_categorical_accuracy: 0.8207
# Epoch 22/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0016 - categorical_accuracy: 0.8242 - val_loss: 0.8719 - val_categorical_accuracy: 0.8242
# Epoch 23/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0017 - categorical_accuracy: 0.8275 - val_loss: 0.8635 - val_categorical_accuracy: 0.8274
# Epoch 24/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0017 - categorical_accuracy: 0.8306 - val_loss: 0.8127 - val_categorical_accuracy: 0.8309
# Epoch 25/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0013 - categorical_accuracy: 0.8338 - val_loss: 0.8143 - val_categorical_accuracy: 0.8341
# Epoch 26/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0021 - categorical_accuracy: 0.8368 - val_loss: 0.8041 - val_categorical_accuracy: 0.8371
# Epoch 27/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0018 - categorical_accuracy: 0.8396 - val_loss: 0.7900 - val_categorical_accuracy: 0.8400
# Epoch 28/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0014 - categorical_accuracy: 0.8424 - val_loss: 0.8732 - val_categorical_accuracy: 0.8421
# Epoch 29/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0016 - categorical_accuracy: 0.8443 - val_loss: 0.9328 - val_categorical_accuracy: 0.8440
# Epoch 30/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0013 - categorical_accuracy: 0.8461 - val_loss: 0.9121 - val_categorical_accuracy: 0.8458
# Epoch 31/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0013 - categorical_accuracy: 0.8478 - val_loss: 0.8902 - val_categorical_accuracy: 0.8475
# Epoch 32/100
# 5/5 [==============================] - 6s 1s/step - loss: 9.8998e-04 - categorical_accuracy: 0.8494 - val_loss: 0.9289 - val_categorical_accuracy: 0.8493
# Epoch 33/100
# 5/5 [==============================] - 6s 1s/step - loss: 8.7601e-04 - categorical_accuracy: 0.8511 - val_loss: 1.0019 - val_categorical_accuracy: 0.8507
# Epoch 34/100
# 5/5 [==============================] - 6s 1s/step - loss: 9.5087e-04 - categorical_accuracy: 0.8524 - val_loss: 1.0562 - val_categorical_accuracy: 0.8518
# Epoch 35/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0010 - categorical_accuracy: 0.8535 - val_loss: 1.0716 - val_categorical_accuracy: 0.8529
# Epoch 36/100
# 5/5 [==============================] - 6s 1s/step - loss: 7.5567e-04 - categorical_accuracy: 0.8545 - val_loss: 1.0965 - val_categorical_accuracy: 0.8538
# Epoch 37/100
# 5/5 [==============================] - 6s 1s/step - loss: 7.4291e-04 - categorical_accuracy: 0.8553 - val_loss: 1.0967 - val_categorical_accuracy: 0.8547
# Epoch 38/100
# 5/5 [==============================] - 6s 1s/step - loss: 9.8362e-04 - categorical_accuracy: 0.8562 - val_loss: 1.1044 - val_categorical_accuracy: 0.8555
# Epoch 39/100
# 5/5 [==============================] - 6s 1s/step - loss: 8.5898e-04 - categorical_accuracy: 0.8569 - val_loss: 1.1342 - val_categorical_accuracy: 0.8561
# Epoch 40/100
# 5/5 [==============================] - 6s 1s/step - loss: 8.7616e-04 - categorical_accuracy: 0.8575 - val_loss: 1.1374 - val_categorical_accuracy: 0.8567
# Epoch 41/100
# 5/5 [==============================] - 6s 1s/step - loss: 9.3888e-04 - categorical_accuracy: 0.8581 - val_loss: 1.1430 - val_categorical_accuracy: 0.8573
# Epoch 42/100
# 5/5 [==============================] - 6s 1s/step - loss: 7.1467e-04 - categorical_accuracy: 0.8586 - val_loss: 1.1476 - val_categorical_accuracy: 0.8578
# Epoch 43/100
# 5/5 [==============================] - 6s 1s/step - loss: 7.4491e-04 - categorical_accuracy: 0.8592 - val_loss: 1.1384 - val_categorical_accuracy: 0.8585
# Epoch 44/100
# 5/5 [==============================] - 6s 1s/step - loss: 5.0546e-04 - categorical_accuracy: 0.8598 - val_loss: 1.2050 - val_categorical_accuracy: 0.8590
# Epoch 45/100
# 5/5 [==============================] - 6s 1s/step - loss: 8.0632e-04 - categorical_accuracy: 0.8602 - val_loss: 1.2178 - val_categorical_accuracy: 0.8596
# Epoch 46/100
# 5/5 [==============================] - 6s 1s/step - loss: 5.8557e-04 - categorical_accuracy: 0.8607 - val_loss: 1.3128 - val_categorical_accuracy: 0.8601
# Epoch 47/100
# 5/5 [==============================] - 6s 1s/step - loss: 4.9195e-04 - categorical_accuracy: 0.8612 - val_loss: 1.3704 - val_categorical_accuracy: 0.8605
# Epoch 48/100
# 5/5 [==============================] - 6s 1s/step - loss: 4.3617e-04 - categorical_accuracy: 0.8617 - val_loss: 1.4186 - val_categorical_accuracy: 0.8608
# Epoch 49/100
# 5/5 [==============================] - 6s 1s/step - loss: 6.7599e-04 - categorical_accuracy: 0.8619 - val_loss: 1.3861 - val_categorical_accuracy: 0.8612
# Epoch 50/100
# 5/5 [==============================] - 6s 1s/step - loss: 4.6776e-04 - categorical_accuracy: 0.8622 - val_loss: 1.3631 - val_categorical_accuracy: 0.8616
# Epoch 51/100
# 5/5 [==============================] - 6s 1s/step - loss: 4.3905e-04 - categorical_accuracy: 0.8626 - val_loss: 1.4220 - val_categorical_accuracy: 0.8619
# Epoch 52/100
# 5/5 [==============================] - 6s 1s/step - loss: 4.7586e-04 - categorical_accuracy: 0.8629 - val_loss: 1.4593 - val_categorical_accuracy: 0.8622
# Epoch 53/100
# 5/5 [==============================] - 6s 1s/step - loss: 3.9628e-04 - categorical_accuracy: 0.8632 - val_loss: 1.4834 - val_categorical_accuracy: 0.8625
# Epoch 54/100
# 5/5 [==============================] - 6s 1s/step - loss: 3.5831e-04 - categorical_accuracy: 0.8634 - val_loss: 1.4439 - val_categorical_accuracy: 0.8628
# Epoch 55/100
# 5/5 [==============================] - 6s 1s/step - loss: 7.7567e-04 - categorical_accuracy: 0.8638 - val_loss: 1.3482 - val_categorical_accuracy: 0.8633
# Epoch 56/100
# 5/5 [==============================] - 6s 1s/step - loss: 3.1059e-04 - categorical_accuracy: 0.8642 - val_loss: 1.4114 - val_categorical_accuracy: 0.8637
# Epoch 57/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0011 - categorical_accuracy: 0.8647 - val_loss: 1.4151 - val_categorical_accuracy: 0.8641
# Epoch 58/100
# 5/5 [==============================] - 6s 1s/step - loss: 4.7031e-04 - categorical_accuracy: 0.8650 - val_loss: 1.3568 - val_categorical_accuracy: 0.8644
# Epoch 59/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0011 - categorical_accuracy: 0.8651 - val_loss: 1.5360 - val_categorical_accuracy: 0.8646
# Epoch 60/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.9876e-04 - categorical_accuracy: 0.8654 - val_loss: 1.7200 - val_categorical_accuracy: 0.8649
# Epoch 61/100
# 5/5 [==============================] - 6s 1s/step - loss: 3.3367e-04 - categorical_accuracy: 0.8657 - val_loss: 1.6660 - val_categorical_accuracy: 0.8652
# Epoch 62/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.5384e-04 - categorical_accuracy: 0.8660 - val_loss: 1.4942 - val_categorical_accuracy: 0.8655
# Epoch 63/100
# 5/5 [==============================] - 6s 1s/step - loss: 3.1436e-04 - categorical_accuracy: 0.8663 - val_loss: 1.4458 - val_categorical_accuracy: 0.8658
# Epoch 64/100
# 5/5 [==============================] - 6s 1s/step - loss: 3.1550e-04 - categorical_accuracy: 0.8666 - val_loss: 1.4611 - val_categorical_accuracy: 0.8661
# Epoch 65/100
# 5/5 [==============================] - 6s 1s/step - loss: 3.9223e-04 - categorical_accuracy: 0.8668 - val_loss: 1.4528 - val_categorical_accuracy: 0.8663
# Epoch 66/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.7162e-04 - categorical_accuracy: 0.8671 - val_loss: 1.3241 - val_categorical_accuracy: 0.8668
# Epoch 67/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.6475e-04 - categorical_accuracy: 0.8676 - val_loss: 1.2617 - val_categorical_accuracy: 0.8673
# Epoch 68/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.7005e-04 - categorical_accuracy: 0.8681 - val_loss: 1.2365 - val_categorical_accuracy: 0.8678
# Epoch 69/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.1099e-04 - categorical_accuracy: 0.8685 - val_loss: 1.2523 - val_categorical_accuracy: 0.8683
# Epoch 70/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.4456e-04 - categorical_accuracy: 0.8690 - val_loss: 1.2772 - val_categorical_accuracy: 0.8688
# Epoch 71/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.7349e-04 - categorical_accuracy: 0.8695 - val_loss: 1.2565 - val_categorical_accuracy: 0.8691
# Epoch 72/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.5050e-04 - categorical_accuracy: 0.8698 - val_loss: 1.2409 - val_categorical_accuracy: 0.8695
# Epoch 73/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.6433e-04 - categorical_accuracy: 0.8702 - val_loss: 1.2257 - val_categorical_accuracy: 0.8699
# Epoch 74/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.3347e-04 - categorical_accuracy: 0.8706 - val_loss: 1.1669 - val_categorical_accuracy: 0.8704
# Epoch 75/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.2867e-04 - categorical_accuracy: 0.8711 - val_loss: 1.0738 - val_categorical_accuracy: 0.8710
# Epoch 76/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.9273e-04 - categorical_accuracy: 0.8717 - val_loss: 1.0423 - val_categorical_accuracy: 0.8715
# Epoch 77/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.6865e-04 - categorical_accuracy: 0.8722 - val_loss: 1.0296 - val_categorical_accuracy: 0.8721
# Epoch 78/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.7813e-04 - categorical_accuracy: 0.8727 - val_loss: 1.0383 - val_categorical_accuracy: 0.8726
# Epoch 79/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.9109e-04 - categorical_accuracy: 0.8732 - val_loss: 1.0032 - val_categorical_accuracy: 0.8731
# Epoch 80/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.3211e-04 - categorical_accuracy: 0.8737 - val_loss: 0.9708 - val_categorical_accuracy: 0.8736
# Epoch 81/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.8052e-04 - categorical_accuracy: 0.8742 - val_loss: 0.9069 - val_categorical_accuracy: 0.8742
# Epoch 82/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.2817e-04 - categorical_accuracy: 0.8748 - val_loss: 0.8687 - val_categorical_accuracy: 0.8747
# Epoch 83/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.6036e-04 - categorical_accuracy: 0.8753 - val_loss: 0.8547 - val_categorical_accuracy: 0.8752
# Epoch 84/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.1089e-04 - categorical_accuracy: 0.8758 - val_loss: 0.8667 - val_categorical_accuracy: 0.8756
# Epoch 85/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.3991e-04 - categorical_accuracy: 0.8762 - val_loss: 0.8764 - val_categorical_accuracy: 0.8761
# Epoch 86/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.7586e-04 - categorical_accuracy: 0.8766 - val_loss: 0.7874 - val_categorical_accuracy: 0.8766
# Epoch 87/100
# 5/5 [==============================] - 6s 1s/step - loss: 2.1053e-04 - categorical_accuracy: 0.8772 - val_loss: 0.7202 - val_categorical_accuracy: 0.8772
# Epoch 88/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.7413e-04 - categorical_accuracy: 0.8778 - val_loss: 0.7243 - val_categorical_accuracy: 0.8779
# Epoch 89/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.7809e-04 - categorical_accuracy: 0.8784 - val_loss: 0.7759 - val_categorical_accuracy: 0.8784
# Epoch 90/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.2672e-04 - categorical_accuracy: 0.8790 - val_loss: 0.8013 - val_categorical_accuracy: 0.8789
# Epoch 91/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.3392e-04 - categorical_accuracy: 0.8794 - val_loss: 0.7951 - val_categorical_accuracy: 0.8794
# Epoch 92/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.9758e-04 - categorical_accuracy: 0.8799 - val_loss: 0.7484 - val_categorical_accuracy: 0.8799
# Epoch 93/100
# 5/5 [==============================] - 6s 1s/step - loss: 8.4804e-05 - categorical_accuracy: 0.8804 - val_loss: 0.7072 - val_categorical_accuracy: 0.8805
# Epoch 94/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.0599e-04 - categorical_accuracy: 0.8810 - val_loss: 0.6985 - val_categorical_accuracy: 0.8810
# Epoch 95/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.1515e-04 - categorical_accuracy: 0.8816 - val_loss: 0.6969 - val_categorical_accuracy: 0.8816
# Epoch 96/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.0870e-04 - categorical_accuracy: 0.8821 - val_loss: 0.6823 - val_categorical_accuracy: 0.8822
# Epoch 97/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.1055e-04 - categorical_accuracy: 0.8827 - val_loss: 0.6831 - val_categorical_accuracy: 0.8827
# Epoch 98/100
# 5/5 [==============================] - 6s 1s/step - loss: 7.2063e-05 - categorical_accuracy: 0.8832 - val_loss: 0.6914 - val_categorical_accuracy: 0.8833
# Epoch 99/100
# 5/5 [==============================] - 6s 1s/step - loss: 8.5186e-05 - categorical_accuracy: 0.8838 - val_loss: 0.6836 - val_categorical_accuracy: 0.8838
# Epoch 100/100
# 5/5 [==============================] - 6s 1s/step - loss: 1.0251e-04 - categorical_accuracy: 0.8843 - val_loss: 0.6814 - val_categorical_accuracy: 0.8844

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
plt.plot(hist.history['categorical_accuracy'])
plt.plot(hist.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred=model.predict(X_test) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_test, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 8  2  0]
#  [ 8  0  0]
#  [13  9 13]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.39622641509433965

# %%
model.save_weights('/content/gdrive/MyDrive/VGG_PECLESS')

# %%
model2 = generate_vgg_model(l_e.classes_.size)

# %%
model2.load_weights('/content/gdrive/MyDrive/VGG_PECLESS')

# %%
y_pred=model2.predict(X_val) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_val, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[17 15  2]
#  [ 6 28  0]
#  [ 1 10 23]]
