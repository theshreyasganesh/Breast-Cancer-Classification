# %%
import os 
os.environ['TF_KERAS'] = '1'
# %env TF_KERAS = 1
from tensorflow.keras.losses import CategoricalCrossentropy, BinaryCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy, BinaryAccuracy
from tensorflow.keras.optimizers import Adam
from tensorflow.python.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import random

from imutils import paths
import numpy as np
import pandas as pd
import skimage as sk
import skimage.transform
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
import json

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import accuracy_score, auc, classification_report, confusion_matrix, roc_curve
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
import ssl

from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Concatenate, Dense, Dropout, Flatten, Input
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
# Out:
# env: TF_KERAS=1

# %%
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf




def show_raw_image(img) -> None:
    """
    Displays a PIL image.
    :param img: the image in PIL format (before being converted to an array).
    :return: None.
    """
    img.show()




def create_label_encoder():
   
    return LabelEncoder()

# %%
# Constants
RANDOM_SEED = 111
VGG_IMG_SIZE = {
    "HEIGHT": 512,
    "WIDTH": 512
}
VGG_IMG_SIZE_LARGE = {
    "HEIGHT": 2048,
    "WIDTH": 2048
}
BATCH_SIZE = 2
EPOCH_1 = 150
EPOCH_2 = 50

# Variables set by command line arguments/flags
dataset = "mini-MIAS"   # The dataset to use.
model = "advanced"         # The model to use.
run_mode = "training"   # The type of running mode, either training or testing.
verbose_mode = False    # Boolean used to print additional logs for debugging purposes.
imagesize = "small"

# %%
def preprocess_image(image_path: str) -> np.ndarray:
 
    image = load_img(image_path,
                     color_mode="grayscale",
                     target_size=(VGG_IMG_SIZE['HEIGHT'], VGG_IMG_SIZE["WIDTH"]))
    image = img_to_array(image)
    image /= 255.0
    return image

def encode_labels(labels_list: np.ndarray, label_encoder) -> np.ndarray:
  
    labels = label_encoder.fit_transform(labels_list)
    if label_encoder.classes_.size == 2:
        return labels
    else:
        return to_categorical(labels)

def dataset_stratified_split(split: float, dataset: np.ndarray, labels: np.ndarray) -> \
        (np.ndarray, np.ndarray, np.ndarray, np.ndarray):
    
    train_X, test_X, train_Y, test_Y = train_test_split(dataset,
                                                        labels,
                                                        test_size=split,
                                                        stratify=labels,
                                                        random_state=RANDOM_SEED,
                                                        shuffle=True)
    return train_X, test_X, train_Y, test_Y


def random_rotation(image_array: np.ndarray):
    """
    Randomly rotate the image
    :param image_array: input image
    :return: randomly rotated image
    """
    random_degree = random.uniform(-20, 20)
    return sk.transform.rotate(image_array, random_degree)


def random_noise(image_array: np.ndarray):
    """
    Add random noise to image
    :param image_array: input image
    :return: image with added random noise
    """
    return sk.util.random_noise(image_array)


def horizontal_flip(image_array: np.ndarray):
    """
    Flip image
    :param image_array: input image
    :return: horizantally flipped image
    """
    return image_array[:, ::-1]




def create_individual_transform(image: np.array, transforms: dict):
    """
    Create transformation of an individual image
    :param image: input image
    :param transforms: the possible transforms to do on the image
    :return: transformed image
    """
    num_transformations_to_apply = random.randint(1, len(transforms))
    num_transforms = 0
    transformed_image = None
    while num_transforms <= num_transformations_to_apply:
        key = random.choice(list(transforms))
        transformed_image = transforms[key](image)
        num_transforms += 1

    return transformed_image


def get_class_balances(y_vals):
    """
    Count occurrences of each class.
    :param y_vals: labels
    :return: array count of each class
    """
    num_classes = len(y_vals[0])
    counts = np.zeros(num_classes)
    for y_val in y_vals:
        for i in range(num_classes):
            counts[i] += y_val[i]

    return (counts.tolist())



def import_minimias_dataset(data_dir: str, label_encoder) -> (np.ndarray, np.ndarray):
    """
    Import the dataset by pre-processing the images and encoding the labels.
    :param data_dir: Directory to the mini-MIAS images.
    :param label_encoder: The label encoder.
    :return: Two NumPy arrays, one for the processed images and one for the encoded labels.
    """
    # Initialise variables.
    images = list()
    labels = list()

    for image_path in list(paths.list_images(data_dir)):
        images.append(preprocess_image(image_path))
        labels.append(image_path.split(os.path.sep)[-2])  # Extract label from path.

    images = np.array(images, dtype="float32")  # Convert images to a batch.
    classes=labels
    labels = np.array(labels)

    # Encode labels.
    labels = encode_labels(labels, label_encoder)

    return images, labels, classes

# %%
def generate_image_transforms(images, labels):
    """
    oversample data by tranforming existing images
    :param images: input images
    :param labels: input labels
    :return: updated list of images and labels with extra transformed images and labels
    """
    images_with_transforms = images
    labels_with_transforms = labels

    available_transforms = {'rotate': random_rotation,
                            'noise': random_noise,
                            'horizontal_flip': horizontal_flip}

    class_balance = get_class_balances(labels)
    max_count = max(class_balance)
    to_add = [max_count - i for i in class_balance]

    for i in range(len(to_add)):
        if int(to_add[i]) == 0:
            continue
        label = np.zeros(len(to_add))
        label[i] = 1
        indices = [j for j, x in enumerate(labels) if np.array_equal(x, label)]
        indiv_class_images = [images[j] for j in indices]

        for k in range(int(to_add[i])):
            a = create_individual_transform(indiv_class_images[k % len(indiv_class_images)], available_transforms)
            transformed_image = create_individual_transform(indiv_class_images[k % len(indiv_class_images)],
                                                            available_transforms)
            transformed_image = transformed_image.reshape(1, VGG_IMG_SIZE['HEIGHT'],
                                                          VGG_IMG_SIZE['WIDTH'], 1)

            images_with_transforms = np.append(images_with_transforms, transformed_image, axis=0)
            transformed_label = label.reshape(1, len(label))
            labels_with_transforms = np.append(labels_with_transforms, transformed_label, axis=0)

    return images_with_transforms, labels_with_transforms

# %%
l_e = create_label_encoder()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
images, labels,classes = import_minimias_dataset(data_dir="/content/drive/MyDrive/Pec_removed_mini_mias".format("mini-MIAS"),
                                                     label_encoder=l_e)

# %%
X_train, X_test, y_train, y_test = dataset_stratified_split(split=0.20, dataset=images, labels=labels)
X_train_rebalanced, y_train_rebalanced = generate_image_transforms(X_train, y_train)
X_train, X_val, y_train, y_val = dataset_stratified_split(split=0.25, dataset=X_train_rebalanced,
                                                                      labels=y_train_rebalanced)

# %%
import pandas as pd
classes=pd.DataFrame(classes)
classes[0].value_counts()
# Out:
# normal_cases       171
# benign_cases        51
# malignant_cases     48
# Name: 0, dtype: int64

# %%
classes[0].value_counts()[:20].plot(kind='barh')

# %%
def create_basic_cnn_model(num_classes: int):
    """
    Function to create a basic CNN.
    :param num_classes: The number of classes (labels).
    :return: A basic CNN model.
    """
    model = Sequential()

    # Convolutional + spooling layers
    model.add(Conv2D(64, (5, 5), input_shape=(512, 512, 1)))
    model.add(Conv2D(64, (5, 5), padding='same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(64, (5, 5), padding='same'))
    model.add(Conv2D(32, (5, 5), padding='same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Flatten())

    # Dropout
    model.add(Dropout(0.5, seed=RANDOM_SEED, name="Dropout_1"))

    # FC
    model.add(Dense(512, activation='relu', name='Dense_2'))

    # Output
    if num_classes == 2:
        model.add(Dense(1, activation='sigmoid', kernel_initializer="random_uniform", name='Output'))
    else:
        model.add(Dense(num_classes, activation='softmax', kernel_initializer="random_uniform", name='Output'))
        print(model.summary())

    return model

# %%
model = create_basic_cnn_model(l_e.classes_.size)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 508, 508, 64)      1664
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 508, 508, 64)      102464
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 254, 254, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 254, 254, 64)      102464
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 254, 254, 32)      51232
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 127, 127, 32)      0
# _________________________________________________________________
# module_wrapper (ModuleWrappe (None, 516128)            0
# _________________________________________________________________
# module_wrapper_1 (ModuleWrap (None, 516128)            0
# _________________________________________________________________
# module_wrapper_2 (ModuleWrap (None, 512)               264258048
# _________________________________________________________________
# module_wrapper_3 (ModuleWrap (None, 3)                 1539
# =================================================================
# Total params: 264,517,411
# Trainable params: 264,517,411
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
    # Freeze VGG19 pre-trained layers.
   


    # Train model with frozen layers (all training with early stopping dictated by loss in validation over 3 runs).


model.compile(optimizer='adam',loss=CategoricalCrossentropy(),metrics=[CategoricalAccuracy()])
hist = model.fit(X_train,
                 y_train,
                 validation_data=(X_val, y_val),

                 epochs=100,
                 batch_size=16,
                 )
# Out:
# Epoch 1/100
# 20/20 [==============================] - 35s 1s/step - loss: 20.1354 - categorical_accuracy: 0.3735 - val_loss: 5.6745 - val_categorical_accuracy: 0.3681
# Epoch 2/100
# 20/20 [==============================] - 17s 853ms/step - loss: 1.9194 - categorical_accuracy: 0.3704 - val_loss: 1.1313 - val_categorical_accuracy: 0.3734
# Epoch 3/100
# 20/20 [==============================] - 17s 848ms/step - loss: 1.0603 - categorical_accuracy: 0.3569 - val_loss: 1.0938 - val_categorical_accuracy: 0.3543
# Epoch 4/100
# 20/20 [==============================] - 17s 861ms/step - loss: 1.0680 - categorical_accuracy: 0.3623 - val_loss: 1.1325 - val_categorical_accuracy: 0.3684
# Epoch 5/100
# 20/20 [==============================] - 17s 873ms/step - loss: 1.0251 - categorical_accuracy: 0.3785 - val_loss: 1.2868 - val_categorical_accuracy: 0.3891
# Epoch 6/100
# 20/20 [==============================] - 18s 880ms/step - loss: 1.0619 - categorical_accuracy: 0.3896 - val_loss: 1.1438 - val_categorical_accuracy: 0.3893
# Epoch 7/100
# 20/20 [==============================] - 18s 877ms/step - loss: 1.0255 - categorical_accuracy: 0.3915 - val_loss: 1.1712 - val_categorical_accuracy: 0.3961
# Epoch 8/100
# 20/20 [==============================] - 18s 880ms/step - loss: 0.9910 - categorical_accuracy: 0.4001 - val_loss: 1.1907 - val_categorical_accuracy: 0.4045
# Epoch 9/100
# 20/20 [==============================] - 18s 881ms/step - loss: 0.9476 - categorical_accuracy: 0.4083 - val_loss: 1.0842 - val_categorical_accuracy: 0.4131
# Epoch 10/100
# 20/20 [==============================] - 18s 880ms/step - loss: 0.9758 - categorical_accuracy: 0.4158 - val_loss: 1.1581 - val_categorical_accuracy: 0.4186
# Epoch 11/100
# 20/20 [==============================] - 17s 871ms/step - loss: 0.9907 - categorical_accuracy: 0.4204 - val_loss: 1.0775 - val_categorical_accuracy: 0.4236
# Epoch 12/100
# 20/20 [==============================] - 17s 875ms/step - loss: 1.0015 - categorical_accuracy: 0.4257 - val_loss: 1.0933 - val_categorical_accuracy: 0.4274
# Epoch 13/100
# 20/20 [==============================] - 17s 874ms/step - loss: 0.9562 - categorical_accuracy: 0.4309 - val_loss: 1.1556 - val_categorical_accuracy: 0.4327
# Epoch 14/100
# 20/20 [==============================] - 18s 888ms/step - loss: 0.9267 - categorical_accuracy: 0.4357 - val_loss: 1.1006 - val_categorical_accuracy: 0.4379
# Epoch 15/100
# 20/20 [==============================] - 18s 888ms/step - loss: 0.8892 - categorical_accuracy: 0.4394 - val_loss: 1.0062 - val_categorical_accuracy: 0.4419
# Epoch 16/100
# 20/20 [==============================] - 18s 889ms/step - loss: 0.8575 - categorical_accuracy: 0.4452 - val_loss: 1.0896 - val_categorical_accuracy: 0.4483
# Epoch 17/100
# 20/20 [==============================] - 18s 889ms/step - loss: 0.7841 - categorical_accuracy: 0.4509 - val_loss: 1.6786 - val_categorical_accuracy: 0.4554
# Epoch 18/100
# 20/20 [==============================] - 18s 890ms/step - loss: 0.7895 - categorical_accuracy: 0.4588 - val_loss: 1.0986 - val_categorical_accuracy: 0.4613
# Epoch 19/100
# 20/20 [==============================] - 18s 890ms/step - loss: 0.7132 - categorical_accuracy: 0.4660 - val_loss: 1.2303 - val_categorical_accuracy: 0.4705
# Epoch 20/100
# 20/20 [==============================] - 18s 891ms/step - loss: 0.5941 - categorical_accuracy: 0.4771 - val_loss: 1.4730 - val_categorical_accuracy: 0.4822
# Epoch 21/100
# 20/20 [==============================] - 18s 890ms/step - loss: 0.6177 - categorical_accuracy: 0.4879 - val_loss: 1.1378 - val_categorical_accuracy: 0.4928
# Epoch 22/100
# 20/20 [==============================] - 18s 891ms/step - loss: 0.5462 - categorical_accuracy: 0.4974 - val_loss: 2.8488 - val_categorical_accuracy: 0.5021
# Epoch 23/100
# 20/20 [==============================] - 18s 890ms/step - loss: 0.3139 - categorical_accuracy: 0.5087 - val_loss: 1.3853 - val_categorical_accuracy: 0.5153
# Epoch 24/100
# 20/20 [==============================] - 18s 892ms/step - loss: 0.1844 - categorical_accuracy: 0.5225 - val_loss: 3.0230 - val_categorical_accuracy: 0.5288
# Epoch 25/100
# 20/20 [==============================] - 18s 890ms/step - loss: 0.7605 - categorical_accuracy: 0.5343 - val_loss: 2.5380 - val_categorical_accuracy: 0.5376
# Epoch 26/100
# 20/20 [==============================] - 18s 890ms/step - loss: 0.2164 - categorical_accuracy: 0.5436 - val_loss: 3.3306 - val_categorical_accuracy: 0.5488
# Epoch 27/100
# 20/20 [==============================] - 18s 890ms/step - loss: 0.1358 - categorical_accuracy: 0.5545 - val_loss: 2.1649 - val_categorical_accuracy: 0.5595
# Epoch 28/100
# 20/20 [==============================] - 18s 891ms/step - loss: 0.1429 - categorical_accuracy: 0.5653 - val_loss: 3.1174 - val_categorical_accuracy: 0.5704
# Epoch 29/100
# 20/20 [==============================] - 18s 890ms/step - loss: 0.0476 - categorical_accuracy: 0.5762 - val_loss: 2.3541 - val_categorical_accuracy: 0.5812
# Epoch 30/100
# 20/20 [==============================] - 18s 891ms/step - loss: 0.0085 - categorical_accuracy: 0.5868 - val_loss: 2.2544 - val_categorical_accuracy: 0.5916
# Epoch 31/100
# 20/20 [==============================] - 18s 890ms/step - loss: 0.0040 - categorical_accuracy: 0.5970 - val_loss: 2.3564 - val_categorical_accuracy: 0.6015
# Epoch 32/100
# 20/20 [==============================] - 18s 890ms/step - loss: 0.0019 - categorical_accuracy: 0.6067 - val_loss: 2.4365 - val_categorical_accuracy: 0.6108
# Epoch 33/100
# 20/20 [==============================] - 18s 890ms/step - loss: 0.0014 - categorical_accuracy: 0.6156 - val_loss: 2.4873 - val_categorical_accuracy: 0.6194
# Epoch 34/100
# 20/20 [==============================] - 18s 891ms/step - loss: 0.0011 - categorical_accuracy: 0.6240 - val_loss: 2.5174 - val_categorical_accuracy: 0.6276
# Epoch 35/100
# 20/20 [==============================] - 18s 890ms/step - loss: 9.0322e-04 - categorical_accuracy: 0.6319 - val_loss: 2.5429 - val_categorical_accuracy: 0.6354
# Epoch 36/100
# 20/20 [==============================] - 18s 890ms/step - loss: 7.1769e-04 - categorical_accuracy: 0.6394 - val_loss: 2.5663 - val_categorical_accuracy: 0.6427
# Epoch 37/100
# 20/20 [==============================] - 18s 891ms/step - loss: 6.7069e-04 - categorical_accuracy: 0.6466 - val_loss: 2.5887 - val_categorical_accuracy: 0.6497
# Epoch 38/100
# 20/20 [==============================] - 18s 890ms/step - loss: 6.5551e-04 - categorical_accuracy: 0.6534 - val_loss: 2.6062 - val_categorical_accuracy: 0.6563
# Epoch 39/100
# 20/20 [==============================] - 18s 891ms/step - loss: 6.1937e-04 - categorical_accuracy: 0.6598 - val_loss: 2.6299 - val_categorical_accuracy: 0.6626
# Epoch 40/100
# 20/20 [==============================] - 18s 890ms/step - loss: 4.8142e-04 - categorical_accuracy: 0.6658 - val_loss: 2.6498 - val_categorical_accuracy: 0.6685
# Epoch 41/100
# 20/20 [==============================] - 18s 890ms/step - loss: 4.4358e-04 - categorical_accuracy: 0.6716 - val_loss: 2.6728 - val_categorical_accuracy: 0.6741
# Epoch 42/100
# 20/20 [==============================] - 18s 892ms/step - loss: 3.7501e-04 - categorical_accuracy: 0.6770 - val_loss: 2.6913 - val_categorical_accuracy: 0.6794
# Epoch 43/100
# 20/20 [==============================] - 18s 890ms/step - loss: 3.5640e-04 - categorical_accuracy: 0.6823 - val_loss: 2.7117 - val_categorical_accuracy: 0.6845
# Epoch 44/100
# 20/20 [==============================] - 18s 890ms/step - loss: 3.5108e-04 - categorical_accuracy: 0.6872 - val_loss: 2.7304 - val_categorical_accuracy: 0.6894
# Epoch 45/100
# 20/20 [==============================] - 18s 891ms/step - loss: 3.2462e-04 - categorical_accuracy: 0.6920 - val_loss: 2.7456 - val_categorical_accuracy: 0.6940
# Epoch 46/100
# 20/20 [==============================] - 18s 891ms/step - loss: 3.5520e-04 - categorical_accuracy: 0.6965 - val_loss: 2.7595 - val_categorical_accuracy: 0.6984
# Epoch 47/100
# 20/20 [==============================] - 18s 891ms/step - loss: 2.8832e-04 - categorical_accuracy: 0.7008 - val_loss: 2.7736 - val_categorical_accuracy: 0.7027
# Epoch 48/100
# 20/20 [==============================] - 18s 891ms/step - loss: 2.4303e-04 - categorical_accuracy: 0.7050 - val_loss: 2.7859 - val_categorical_accuracy: 0.7068
# Epoch 49/100
# 20/20 [==============================] - 18s 891ms/step - loss: 2.7817e-04 - categorical_accuracy: 0.7090 - val_loss: 2.8002 - val_categorical_accuracy: 0.7107
# Epoch 50/100
# 20/20 [==============================] - 18s 890ms/step - loss: 2.4737e-04 - categorical_accuracy: 0.7128 - val_loss: 2.8128 - val_categorical_accuracy: 0.7144
# Epoch 51/100
# 20/20 [==============================] - 18s 891ms/step - loss: 2.4860e-04 - categorical_accuracy: 0.7165 - val_loss: 2.8277 - val_categorical_accuracy: 0.7180
# Epoch 52/100
# 20/20 [==============================] - 18s 892ms/step - loss: 2.0744e-04 - categorical_accuracy: 0.7200 - val_loss: 2.8408 - val_categorical_accuracy: 0.7215
# Epoch 53/100
# 20/20 [==============================] - 18s 891ms/step - loss: 2.0211e-04 - categorical_accuracy: 0.7234 - val_loss: 2.8544 - val_categorical_accuracy: 0.7248
# Epoch 54/100
# 20/20 [==============================] - 18s 892ms/step - loss: 1.9833e-04 - categorical_accuracy: 0.7267 - val_loss: 2.8683 - val_categorical_accuracy: 0.7280
# Epoch 55/100
# 20/20 [==============================] - 18s 892ms/step - loss: 1.9792e-04 - categorical_accuracy: 0.7298 - val_loss: 2.8787 - val_categorical_accuracy: 0.7311
# Epoch 56/100
# 20/20 [==============================] - 18s 893ms/step - loss: 2.1578e-04 - categorical_accuracy: 0.7328 - val_loss: 2.8936 - val_categorical_accuracy: 0.7341
# Epoch 57/100
# 20/20 [==============================] - 18s 892ms/step - loss: 1.6944e-04 - categorical_accuracy: 0.7358 - val_loss: 2.9048 - val_categorical_accuracy: 0.7370
# Epoch 58/100
# 20/20 [==============================] - 18s 892ms/step - loss: 1.8937e-04 - categorical_accuracy: 0.7386 - val_loss: 2.9143 - val_categorical_accuracy: 0.7398
# Epoch 59/100
# 20/20 [==============================] - 18s 892ms/step - loss: 1.3434e-04 - categorical_accuracy: 0.7413 - val_loss: 2.9239 - val_categorical_accuracy: 0.7424
# Epoch 60/100
# 20/20 [==============================] - 18s 891ms/step - loss: 1.5280e-04 - categorical_accuracy: 0.7439 - val_loss: 2.9323 - val_categorical_accuracy: 0.7450
# Epoch 61/100
# 20/20 [==============================] - 18s 890ms/step - loss: 1.5420e-04 - categorical_accuracy: 0.7465 - val_loss: 2.9435 - val_categorical_accuracy: 0.7476
# Epoch 62/100
# 20/20 [==============================] - 18s 890ms/step - loss: 1.2951e-04 - categorical_accuracy: 0.7490 - val_loss: 2.9536 - val_categorical_accuracy: 0.7500
# Epoch 63/100
# 20/20 [==============================] - 18s 891ms/step - loss: 1.4158e-04 - categorical_accuracy: 0.7513 - val_loss: 2.9613 - val_categorical_accuracy: 0.7523
# Epoch 64/100
# 20/20 [==============================] - 18s 891ms/step - loss: 1.3047e-04 - categorical_accuracy: 0.7536 - val_loss: 2.9687 - val_categorical_accuracy: 0.7546
# Epoch 65/100
# 20/20 [==============================] - 18s 890ms/step - loss: 1.2559e-04 - categorical_accuracy: 0.7559 - val_loss: 2.9774 - val_categorical_accuracy: 0.7568
# Epoch 66/100
# 20/20 [==============================] - 18s 891ms/step - loss: 1.2083e-04 - categorical_accuracy: 0.7581 - val_loss: 2.9916 - val_categorical_accuracy: 0.7590
# Epoch 67/100
# 20/20 [==============================] - 18s 890ms/step - loss: 1.2363e-04 - categorical_accuracy: 0.7602 - val_loss: 3.0005 - val_categorical_accuracy: 0.7610
# Epoch 68/100
# 20/20 [==============================] - 18s 891ms/step - loss: 1.1861e-04 - categorical_accuracy: 0.7622 - val_loss: 3.0135 - val_categorical_accuracy: 0.7630
# Epoch 69/100
# 20/20 [==============================] - 18s 890ms/step - loss: 1.1039e-04 - categorical_accuracy: 0.7642 - val_loss: 3.0231 - val_categorical_accuracy: 0.7650
# Epoch 70/100
# 20/20 [==============================] - 18s 890ms/step - loss: 8.2761e-05 - categorical_accuracy: 0.7661 - val_loss: 3.0298 - val_categorical_accuracy: 0.7669
# Epoch 71/100
# 20/20 [==============================] - 18s 890ms/step - loss: 1.0594e-04 - categorical_accuracy: 0.7680 - val_loss: 3.0412 - val_categorical_accuracy: 0.7687
# Epoch 72/100
# 20/20 [==============================] - 18s 890ms/step - loss: 1.1155e-04 - categorical_accuracy: 0.7698 - val_loss: 3.0515 - val_categorical_accuracy: 0.7706
# Epoch 73/100
# 20/20 [==============================] - 18s 890ms/step - loss: 8.4191e-05 - categorical_accuracy: 0.7716 - val_loss: 3.0594 - val_categorical_accuracy: 0.7723
# Epoch 74/100
# 20/20 [==============================] - 18s 890ms/step - loss: 9.1594e-05 - categorical_accuracy: 0.7734 - val_loss: 3.0674 - val_categorical_accuracy: 0.7740
# Epoch 75/100
# 20/20 [==============================] - 18s 891ms/step - loss: 9.5494e-05 - categorical_accuracy: 0.7750 - val_loss: 3.0772 - val_categorical_accuracy: 0.7757
# Epoch 76/100
# 20/20 [==============================] - 18s 891ms/step - loss: 9.1178e-05 - categorical_accuracy: 0.7767 - val_loss: 3.0901 - val_categorical_accuracy: 0.7773
# Epoch 77/100
# 20/20 [==============================] - 18s 892ms/step - loss: 9.9789e-05 - categorical_accuracy: 0.7782 - val_loss: 3.1002 - val_categorical_accuracy: 0.7789
# Epoch 78/100
# 20/20 [==============================] - 18s 892ms/step - loss: 8.8648e-05 - categorical_accuracy: 0.7798 - val_loss: 3.1090 - val_categorical_accuracy: 0.7804
# Epoch 79/100
# 20/20 [==============================] - 18s 891ms/step - loss: 7.6001e-05 - categorical_accuracy: 0.7814 - val_loss: 3.1184 - val_categorical_accuracy: 0.7820
# Epoch 80/100
# 20/20 [==============================] - 18s 891ms/step - loss: 7.0987e-05 - categorical_accuracy: 0.7828 - val_loss: 3.1261 - val_categorical_accuracy: 0.7834
# Epoch 81/100
# 20/20 [==============================] - 18s 890ms/step - loss: 8.0858e-05 - categorical_accuracy: 0.7842 - val_loss: 3.1361 - val_categorical_accuracy: 0.7848
# Epoch 82/100
# 20/20 [==============================] - 18s 890ms/step - loss: 8.5071e-05 - categorical_accuracy: 0.7856 - val_loss: 3.1455 - val_categorical_accuracy: 0.7862
# Epoch 83/100
# 20/20 [==============================] - 18s 891ms/step - loss: 6.3306e-05 - categorical_accuracy: 0.7870 - val_loss: 3.1531 - val_categorical_accuracy: 0.7875
# Epoch 84/100
# 20/20 [==============================] - 18s 890ms/step - loss: 7.1073e-05 - categorical_accuracy: 0.7883 - val_loss: 3.1578 - val_categorical_accuracy: 0.7889
# Epoch 85/100
# 20/20 [==============================] - 18s 890ms/step - loss: 6.8062e-05 - categorical_accuracy: 0.7897 - val_loss: 3.1645 - val_categorical_accuracy: 0.7902
# Epoch 86/100
# 20/20 [==============================] - 18s 890ms/step - loss: 6.9879e-05 - categorical_accuracy: 0.7910 - val_loss: 3.1710 - val_categorical_accuracy: 0.7915
# Epoch 87/100
# 20/20 [==============================] - 18s 890ms/step - loss: 6.0775e-05 - categorical_accuracy: 0.7922 - val_loss: 3.1795 - val_categorical_accuracy: 0.7927
# Epoch 88/100
# 20/20 [==============================] - 18s 890ms/step - loss: 6.4320e-05 - categorical_accuracy: 0.7935 - val_loss: 3.1877 - val_categorical_accuracy: 0.7939
# Epoch 89/100
# 20/20 [==============================] - 18s 890ms/step - loss: 6.0640e-05 - categorical_accuracy: 0.7947 - val_loss: 3.1966 - val_categorical_accuracy: 0.7951
# Epoch 90/100
# 20/20 [==============================] - 18s 891ms/step - loss: 5.4980e-05 - categorical_accuracy: 0.7958 - val_loss: 3.2049 - val_categorical_accuracy: 0.7963
# Epoch 91/100
# 20/20 [==============================] - 18s 891ms/step - loss: 5.7246e-05 - categorical_accuracy: 0.7969 - val_loss: 3.2102 - val_categorical_accuracy: 0.7974
# Epoch 92/100
# 20/20 [==============================] - 18s 890ms/step - loss: 5.5637e-05 - categorical_accuracy: 0.7981 - val_loss: 3.2173 - val_categorical_accuracy: 0.7985
# Epoch 93/100
# 20/20 [==============================] - 18s 891ms/step - loss: 5.9265e-05 - categorical_accuracy: 0.7992 - val_loss: 3.2224 - val_categorical_accuracy: 0.7996
# Epoch 94/100
# 20/20 [==============================] - 18s 890ms/step - loss: 4.9723e-05 - categorical_accuracy: 0.8003 - val_loss: 3.2324 - val_categorical_accuracy: 0.8007
# Epoch 95/100
# 20/20 [==============================] - 18s 891ms/step - loss: 4.4865e-05 - categorical_accuracy: 0.8013 - val_loss: 3.2400 - val_categorical_accuracy: 0.8017
# Epoch 96/100
# 20/20 [==============================] - 18s 890ms/step - loss: 5.6553e-05 - categorical_accuracy: 0.8024 - val_loss: 3.2461 - val_categorical_accuracy: 0.8028
# Epoch 97/100
# 20/20 [==============================] - 18s 892ms/step - loss: 5.1729e-05 - categorical_accuracy: 0.8034 - val_loss: 3.2546 - val_categorical_accuracy: 0.8038
# Epoch 98/100
# 20/20 [==============================] - 18s 891ms/step - loss: 4.3936e-05 - categorical_accuracy: 0.8044 - val_loss: 3.2605 - val_categorical_accuracy: 0.8047
# Epoch 99/100
# 20/20 [==============================] - 18s 891ms/step - loss: 4.6783e-05 - categorical_accuracy: 0.8053 - val_loss: 3.2670 - val_categorical_accuracy: 0.8057
# Epoch 100/100
# 20/20 [==============================] - 18s 891ms/step - loss: 4.5972e-05 - categorical_accuracy: 0.8063 - val_loss: 3.2763 - val_categorical_accuracy: 0.8067

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
plt.plot(hist.history['categorical_accuracy'])
plt.plot(hist.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred=model.predict(X_val) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_val, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[16  9  9]
#  [ 5 24  5]
#  [ 9  4 22]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6019417475728155

# %%
model.save_weights('/content/drive/MyDrive/CNN_PECLESS')

# %%
model2 = create_basic_cnn_model(3)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 508, 508, 64)      1664
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 508, 508, 64)      102464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 254, 254, 64)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 254, 254, 64)      102464
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 254, 254, 32)      51232
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 127, 127, 32)      0
# _________________________________________________________________
# module_wrapper_4 (ModuleWrap (None, 516128)            0
# _________________________________________________________________
# module_wrapper_5 (ModuleWrap (None, 516128)            0
# _________________________________________________________________
# module_wrapper_6 (ModuleWrap (None, 512)               264258048
# _________________________________________________________________
# module_wrapper_7 (ModuleWrap (None, 3)                 1539
# =================================================================
# Total params: 264,517,411
# Trainable params: 264,517,411
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.load_weights('/content/drive/MyDrive/CNN_PECLESS')

# %%
y_pred=model2.predict(X_val) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_val, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 1  6 27]
#  [ 0  6 28]
#  [ 0  4 31]]

# %%
X_train, X_test, y_train, y_test = dataset_stratified_split(split=0.20, dataset=images, labels=labels)

# %%
y_pred=model.predict(X_test) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_test, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 0  0 10]
#  [ 3  2  5]
#  [ 9  9 16]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.3333333333333333
