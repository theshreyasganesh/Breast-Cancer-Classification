# %%
import os 
os.environ['TF_KERAS'] = '1'
# %env TF_KERAS = 1
from tensorflow.keras.losses import CategoricalCrossentropy, BinaryCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy, BinaryAccuracy
from tensorflow.keras.optimizers import Adam
from tensorflow.python.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import random

from imutils import paths
import numpy as np
import pandas as pd
import skimage as sk
import skimage.transform
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
import json

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import accuracy_score, auc, classification_report, confusion_matrix, roc_curve
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
import ssl

from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Concatenate, Dense, Dropout, Flatten, Input
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
# Out:
# env: TF_KERAS=1

# %%
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf




def show_raw_image(img) -> None:
    """
    Displays a PIL image.
    :param img: the image in PIL format (before being converted to an array).
    :return: None.
    """
    img.show()




def create_label_encoder():
   
    return LabelEncoder()

# %%
# Constants
RANDOM_SEED = 111
VGG_IMG_SIZE = {
    "HEIGHT": 512,
    "WIDTH": 512
}
VGG_IMG_SIZE_LARGE = {
    "HEIGHT": 2048,
    "WIDTH": 2048
}
BATCH_SIZE = 2
EPOCH_1 = 150
EPOCH_2 = 50

# Variables set by command line arguments/flags
dataset = "mini-MIAS"   # The dataset to use.
model = "advanced"         # The model to use.
run_mode = "training"   # The type of running mode, either training or testing.
verbose_mode = False    # Boolean used to print additional logs for debugging purposes.
imagesize = "small"

# %%
def preprocess_image(image_path: str) -> np.ndarray:
 
    image = load_img(image_path,
                     color_mode="grayscale",
                     target_size=(VGG_IMG_SIZE['HEIGHT'], VGG_IMG_SIZE["WIDTH"]))
    image = img_to_array(image)
    image /= 255.0
    return image

def encode_labels(labels_list: np.ndarray, label_encoder) -> np.ndarray:
  
    labels = label_encoder.fit_transform(labels_list)
    if label_encoder.classes_.size == 2:
        return labels
    else:
        return to_categorical(labels)

def dataset_stratified_split(split: float, dataset: np.ndarray, labels: np.ndarray) -> \
        (np.ndarray, np.ndarray, np.ndarray, np.ndarray):
    
    train_X, test_X, train_Y, test_Y = train_test_split(dataset,
                                                        labels,
                                                        test_size=split,
                                                        stratify=labels,
                                                        random_state=RANDOM_SEED,
                                                        shuffle=True)
    return train_X, test_X, train_Y, test_Y


def random_rotation(image_array: np.ndarray):
    """
    Randomly rotate the image
    :param image_array: input image
    :return: randomly rotated image
    """
    random_degree = random.uniform(-20, 20)
    return sk.transform.rotate(image_array, random_degree)


def random_noise(image_array: np.ndarray):
    """
    Add random noise to image
    :param image_array: input image
    :return: image with added random noise
    """
    return sk.util.random_noise(image_array)


def horizontal_flip(image_array: np.ndarray):
    """
    Flip image
    :param image_array: input image
    :return: horizantally flipped image
    """
    return image_array[:, ::-1]




def create_individual_transform(image: np.array, transforms: dict):
    """
    Create transformation of an individual image
    :param image: input image
    :param transforms: the possible transforms to do on the image
    :return: transformed image
    """
    num_transformations_to_apply = random.randint(1, len(transforms))
    num_transforms = 0
    transformed_image = None
    while num_transforms <= num_transformations_to_apply:
        key = random.choice(list(transforms))
        transformed_image = transforms[key](image)
        num_transforms += 1

    return transformed_image


def get_class_balances(y_vals):
    """
    Count occurrences of each class.
    :param y_vals: labels
    :return: array count of each class
    """
    num_classes = len(y_vals[0])
    counts = np.zeros(num_classes)
    for y_val in y_vals:
        for i in range(num_classes):
            counts[i] += y_val[i]

    return (counts.tolist())



def import_minimias_dataset(data_dir: str, label_encoder) -> (np.ndarray, np.ndarray):
    """
    Import the dataset by pre-processing the images and encoding the labels.
    :param data_dir: Directory to the mini-MIAS images.
    :param label_encoder: The label encoder.
    :return: Two NumPy arrays, one for the processed images and one for the encoded labels.
    """
    # Initialise variables.
    images = list()
    labels = list()

    for image_path in list(paths.list_images(data_dir)):
        images.append(preprocess_image(image_path))
        labels.append(image_path.split(os.path.sep)[-2])  # Extract label from path.

    images = np.array(images, dtype="float32")  # Convert images to a batch.
    classes=labels
    labels = np.array(labels)

    # Encode labels.
    labels = encode_labels(labels, label_encoder)

    return images, labels, classes

# %%
def generate_image_transforms(images, labels):
    """
    oversample data by tranforming existing images
    :param images: input images
    :param labels: input labels
    :return: updated list of images and labels with extra transformed images and labels
    """
    images_with_transforms = images
    labels_with_transforms = labels

    available_transforms = {'rotate': random_rotation,
                            'noise': random_noise,
                            'horizontal_flip': horizontal_flip}

    class_balance = get_class_balances(labels)
    max_count = max(class_balance)
    to_add = [max_count - i for i in class_balance]

    for i in range(len(to_add)):
        if int(to_add[i]) == 0:
            continue
        label = np.zeros(len(to_add))
        label[i] = 1
        indices = [j for j, x in enumerate(labels) if np.array_equal(x, label)]
        indiv_class_images = [images[j] for j in indices]

        for k in range(int(to_add[i])):
            a = create_individual_transform(indiv_class_images[k % len(indiv_class_images)], available_transforms)
            transformed_image = create_individual_transform(indiv_class_images[k % len(indiv_class_images)],
                                                            available_transforms)
            transformed_image = transformed_image.reshape(1, VGG_IMG_SIZE['HEIGHT'],
                                                          VGG_IMG_SIZE['WIDTH'], 1)

            images_with_transforms = np.append(images_with_transforms, transformed_image, axis=0)
            transformed_label = label.reshape(1, len(label))
            labels_with_transforms = np.append(labels_with_transforms, transformed_label, axis=0)

    return images_with_transforms, labels_with_transforms

# %%
l_e = create_label_encoder()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
images, labels,classes = import_minimias_dataset(data_dir="/content/drive/MyDrive/Pec_removed_mini_mias".format("mini-MIAS"),
                                                     label_encoder=l_e)

# %%
X_train, X_test, y_train, y_test = dataset_stratified_split(split=0.20, dataset=images, labels=labels)
X_train_rebalanced, y_train_rebalanced = generate_image_transforms(X_train, y_train)
X_train, X_val, y_train, y_val = dataset_stratified_split(split=0.25, dataset=X_train_rebalanced,
                                                                      labels=y_train_rebalanced)

# %%
import pandas as pd
classes=pd.DataFrame(classes)
classes[0].value_counts()
# Out:
# normal_cases       171
# benign_cases        51
# malignant_cases     48
# Name: 0, dtype: int64

# %%
classes[0].value_counts()[:20].plot(kind='barh')

# %%
import ssl

from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Concatenate, Dense, Dropout, Flatten, Input
from tensorflow.python.keras import Sequential



# Needed to download pre-trained weights for ImageNet
ssl._create_default_https_context = ssl._create_unverified_context


def create_model():
    """
    Function to create an InceptionV3 model pre-trained with custom FC Layers.
    :param num_classes: The number of classes (labels).
    :return: The custom InceptionV3 model.
    """
    # Reconfigure single channel input into a greyscale 3 channel input
    img_input = Input(shape=(512  , 512, 1))
    img_conc = Concatenate()([img_input, img_input, img_input])

    # Generate a InceptionV3 model with pre-trained ImageNet weights, input as given above, excluded fully connected layers.
    model_base = InceptionV3(include_top=False, weights="imagenet", input_tensor=img_conc)

    # Add fully connected layers
    model = Sequential()
    # Start with base model consisting of convolutional layers
    model.add(model_base)

    # Flatten layer to convert each input into a 1D array (no parameters in this layer, just simple pre-processing).
    model.add(Flatten())

    fully_connected = Sequential(name="Fully_Connected")
    # Fully connected layers.
    fully_connected.add(Dropout(0.2, seed=111, name="Dropout_1"))
    fully_connected.add(Dense(units=512, activation='relu', name='Dense_1'))
    #fully_connected.add(Dropout(0.2, name="Dropout_2"))
    fully_connected.add(Dense(units=512, activation='relu', name='Dense_3'))

    fully_connected.add(Dense(units=32, activation='relu', name='Dense_2'))

    # Final output layer that uses softmax activation function (because the classes are exclusive).
    
    fully_connected.add(Dense(3, activation='softmax', kernel_initializer="random_uniform", name='Output'))
  
    model.add(fully_connected)


    return model

# %%
model=create_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 2s 0us/step
# 87924736/87910968 [==============================] - 2s 0us/step

# %%
    # Freeze VGG19 pre-trained layers.
   


    # Train model with frozen layers (all training with early stopping dictated by loss in validation over 3 runs).


model.compile(optimizer='adam',loss=CategoricalCrossentropy(),metrics=[CategoricalAccuracy()])
hist = model.fit(X_train,
                 y_train,
                 validation_data=(X_val, y_val),

                 epochs=100,
                 batch_size=64,
                 )
# Out:
# Epoch 1/100
# 5/5 [==============================] - 22s 4s/step - loss: 3.4889 - categorical_accuracy: 0.3486 - val_loss: 1.1740 - val_categorical_accuracy: 0.3513
# Epoch 2/100
# 5/5 [==============================] - 5s 1s/step - loss: 1.1182 - categorical_accuracy: 0.3437 - val_loss: 1.0986 - val_categorical_accuracy: 0.3333
# Epoch 3/100
# 5/5 [==============================] - 5s 1s/step - loss: 1.1072 - categorical_accuracy: 0.3474 - val_loss: 1.0986 - val_categorical_accuracy: 0.3531
# Epoch 4/100
# 5/5 [==============================] - 5s 1s/step - loss: 1.2926 - categorical_accuracy: 0.3623 - val_loss: 1.0926 - val_categorical_accuracy: 0.3617
# Epoch 5/100
# 5/5 [==============================] - 5s 1s/step - loss: 1.0944 - categorical_accuracy: 0.3585 - val_loss: 1.0986 - val_categorical_accuracy: 0.3559
# Epoch 6/100
# 5/5 [==============================] - 5s 1s/step - loss: 1.1031 - categorical_accuracy: 0.3537 - val_loss: 1.0986 - val_categorical_accuracy: 0.3525
# Epoch 7/100
# 5/5 [==============================] - 5s 1s/step - loss: 1.0986 - categorical_accuracy: 0.3510 - val_loss: 1.0986 - val_categorical_accuracy: 0.3498
# Epoch 8/100
# 5/5 [==============================] - 5s 1s/step - loss: 1.0986 - categorical_accuracy: 0.3497 - val_loss: 1.0986 - val_categorical_accuracy: 0.3477
# Epoch 9/100
# 5/5 [==============================] - 5s 1s/step - loss: 1.0284 - categorical_accuracy: 0.3466 - val_loss: 1.0905 - val_categorical_accuracy: 0.3461
# Epoch 10/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.9741 - categorical_accuracy: 0.3465 - val_loss: 1.0914 - val_categorical_accuracy: 0.3448
# Epoch 11/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.9182 - categorical_accuracy: 0.3478 - val_loss: 1.0986 - val_categorical_accuracy: 0.3511
# Epoch 12/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.8786 - categorical_accuracy: 0.3614 - val_loss: 1.0942 - val_categorical_accuracy: 0.3680
# Epoch 13/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7942 - categorical_accuracy: 0.3782 - val_loss: 1.0978 - val_categorical_accuracy: 0.3833
# Epoch 14/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7619 - categorical_accuracy: 0.3928 - val_loss: 1.0368 - val_categorical_accuracy: 0.3994
# Epoch 15/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7670 - categorical_accuracy: 0.4078 - val_loss: 1.0297 - val_categorical_accuracy: 0.4135
# Epoch 16/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7441 - categorical_accuracy: 0.4203 - val_loss: 1.0975 - val_categorical_accuracy: 0.4234
# Epoch 17/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7339 - categorical_accuracy: 0.4301 - val_loss: 1.0235 - val_categorical_accuracy: 0.4346
# Epoch 18/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7247 - categorical_accuracy: 0.4410 - val_loss: 1.0669 - val_categorical_accuracy: 0.4441
# Epoch 19/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7220 - categorical_accuracy: 0.4496 - val_loss: 1.0759 - val_categorical_accuracy: 0.4523
# Epoch 20/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7197 - categorical_accuracy: 0.4571 - val_loss: 1.0576 - val_categorical_accuracy: 0.4599
# Epoch 21/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7172 - categorical_accuracy: 0.4643 - val_loss: 1.0284 - val_categorical_accuracy: 0.4672
# Epoch 22/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7162 - categorical_accuracy: 0.4716 - val_loss: 1.0885 - val_categorical_accuracy: 0.4730
# Epoch 23/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7149 - categorical_accuracy: 0.4770 - val_loss: 1.1004 - val_categorical_accuracy: 0.4778
# Epoch 24/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7124 - categorical_accuracy: 0.4809 - val_loss: 1.0880 - val_categorical_accuracy: 0.4825
# Epoch 25/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7098 - categorical_accuracy: 0.4857 - val_loss: 1.0476 - val_categorical_accuracy: 0.4873
# Epoch 26/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7075 - categorical_accuracy: 0.4905 - val_loss: 0.9898 - val_categorical_accuracy: 0.4924
# Epoch 27/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7061 - categorical_accuracy: 0.4954 - val_loss: 1.0642 - val_categorical_accuracy: 0.4963
# Epoch 28/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7040 - categorical_accuracy: 0.4990 - val_loss: 1.0839 - val_categorical_accuracy: 0.4998
# Epoch 29/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7023 - categorical_accuracy: 0.5018 - val_loss: 1.0835 - val_categorical_accuracy: 0.5030
# Epoch 30/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.7003 - categorical_accuracy: 0.5055 - val_loss: 1.0701 - val_categorical_accuracy: 0.5060
# Epoch 31/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6988 - categorical_accuracy: 0.5083 - val_loss: 1.0202 - val_categorical_accuracy: 0.5095
# Epoch 32/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6972 - categorical_accuracy: 0.5118 - val_loss: 1.0446 - val_categorical_accuracy: 0.5126
# Epoch 33/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6952 - categorical_accuracy: 0.5146 - val_loss: 1.1009 - val_categorical_accuracy: 0.5149
# Epoch 34/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6947 - categorical_accuracy: 0.5170 - val_loss: 1.0937 - val_categorical_accuracy: 0.5170
# Epoch 35/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6918 - categorical_accuracy: 0.5185 - val_loss: 1.0413 - val_categorical_accuracy: 0.5195
# Epoch 36/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6904 - categorical_accuracy: 0.5212 - val_loss: 1.0056 - val_categorical_accuracy: 0.5223
# Epoch 37/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6881 - categorical_accuracy: 0.5239 - val_loss: 1.0725 - val_categorical_accuracy: 0.5244
# Epoch 38/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6869 - categorical_accuracy: 0.5261 - val_loss: 1.0709 - val_categorical_accuracy: 0.5263
# Epoch 39/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6849 - categorical_accuracy: 0.5277 - val_loss: 1.0456 - val_categorical_accuracy: 0.5283
# Epoch 40/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6832 - categorical_accuracy: 0.5296 - val_loss: 1.0136 - val_categorical_accuracy: 0.5304
# Epoch 41/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6815 - categorical_accuracy: 0.5317 - val_loss: 0.9896 - val_categorical_accuracy: 0.5325
# Epoch 42/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6798 - categorical_accuracy: 0.5337 - val_loss: 0.9694 - val_categorical_accuracy: 0.5346
# Epoch 43/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6787 - categorical_accuracy: 0.5360 - val_loss: 1.0039 - val_categorical_accuracy: 0.5366
# Epoch 44/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6769 - categorical_accuracy: 0.5378 - val_loss: 1.0645 - val_categorical_accuracy: 0.5379
# Epoch 45/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6754 - categorical_accuracy: 0.5391 - val_loss: 1.0784 - val_categorical_accuracy: 0.5392
# Epoch 46/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6740 - categorical_accuracy: 0.5402 - val_loss: 1.0548 - val_categorical_accuracy: 0.5405
# Epoch 47/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6721 - categorical_accuracy: 0.5414 - val_loss: 1.0049 - val_categorical_accuracy: 0.5420
# Epoch 48/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6706 - categorical_accuracy: 0.5428 - val_loss: 0.9714 - val_categorical_accuracy: 0.5436
# Epoch 49/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6692 - categorical_accuracy: 0.5447 - val_loss: 0.9668 - val_categorical_accuracy: 0.5453
# Epoch 50/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6676 - categorical_accuracy: 0.5464 - val_loss: 1.0267 - val_categorical_accuracy: 0.5467
# Epoch 51/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6662 - categorical_accuracy: 0.5476 - val_loss: 1.0500 - val_categorical_accuracy: 0.5477
# Epoch 52/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6648 - categorical_accuracy: 0.5486 - val_loss: 1.0533 - val_categorical_accuracy: 0.5487
# Epoch 53/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6634 - categorical_accuracy: 0.5497 - val_loss: 1.0390 - val_categorical_accuracy: 0.5497
# Epoch 54/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6619 - categorical_accuracy: 0.5506 - val_loss: 1.0251 - val_categorical_accuracy: 0.5508
# Epoch 55/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6605 - categorical_accuracy: 0.5517 - val_loss: 1.0035 - val_categorical_accuracy: 0.5519
# Epoch 56/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6591 - categorical_accuracy: 0.5527 - val_loss: 0.9735 - val_categorical_accuracy: 0.5531
# Epoch 57/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6577 - categorical_accuracy: 0.5540 - val_loss: 0.9800 - val_categorical_accuracy: 0.5543
# Epoch 58/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6564 - categorical_accuracy: 0.5550 - val_loss: 1.0072 - val_categorical_accuracy: 0.5554
# Epoch 59/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6550 - categorical_accuracy: 0.5561 - val_loss: 1.0134 - val_categorical_accuracy: 0.5563
# Epoch 60/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6536 - categorical_accuracy: 0.5570 - val_loss: 1.0107 - val_categorical_accuracy: 0.5571
# Epoch 61/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6524 - categorical_accuracy: 0.5577 - val_loss: 1.0001 - val_categorical_accuracy: 0.5581
# Epoch 62/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6510 - categorical_accuracy: 0.5587 - val_loss: 0.9739 - val_categorical_accuracy: 0.5591
# Epoch 63/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6497 - categorical_accuracy: 0.5598 - val_loss: 0.9532 - val_categorical_accuracy: 0.5602
# Epoch 64/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6484 - categorical_accuracy: 0.5611 - val_loss: 0.9592 - val_categorical_accuracy: 0.5613
# Epoch 65/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6472 - categorical_accuracy: 0.5621 - val_loss: 1.0309 - val_categorical_accuracy: 0.5620
# Epoch 66/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6459 - categorical_accuracy: 0.5627 - val_loss: 1.0560 - val_categorical_accuracy: 0.5626
# Epoch 67/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6447 - categorical_accuracy: 0.5632 - val_loss: 1.0603 - val_categorical_accuracy: 0.5631
# Epoch 68/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6435 - categorical_accuracy: 0.5635 - val_loss: 1.0555 - val_categorical_accuracy: 0.5636
# Epoch 69/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6422 - categorical_accuracy: 0.5641 - val_loss: 1.0351 - val_categorical_accuracy: 0.5642
# Epoch 70/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6410 - categorical_accuracy: 0.5648 - val_loss: 1.0127 - val_categorical_accuracy: 0.5648
# Epoch 71/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6398 - categorical_accuracy: 0.5653 - val_loss: 0.9912 - val_categorical_accuracy: 0.5655
# Epoch 72/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6386 - categorical_accuracy: 0.5659 - val_loss: 0.9705 - val_categorical_accuracy: 0.5662
# Epoch 73/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6374 - categorical_accuracy: 0.5668 - val_loss: 0.9527 - val_categorical_accuracy: 0.5670
# Epoch 74/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6362 - categorical_accuracy: 0.5675 - val_loss: 0.9396 - val_categorical_accuracy: 0.5679
# Epoch 75/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6350 - categorical_accuracy: 0.5685 - val_loss: 0.9292 - val_categorical_accuracy: 0.5687
# Epoch 76/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6340 - categorical_accuracy: 0.5691 - val_loss: 1.0370 - val_categorical_accuracy: 0.5693
# Epoch 77/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6329 - categorical_accuracy: 0.5697 - val_loss: 1.0824 - val_categorical_accuracy: 0.5696
# Epoch 78/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6319 - categorical_accuracy: 0.5699 - val_loss: 1.0735 - val_categorical_accuracy: 0.5699
# Epoch 79/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6306 - categorical_accuracy: 0.5703 - val_loss: 1.0331 - val_categorical_accuracy: 0.5703
# Epoch 80/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6295 - categorical_accuracy: 0.5708 - val_loss: 0.9833 - val_categorical_accuracy: 0.5709
# Epoch 81/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6283 - categorical_accuracy: 0.5713 - val_loss: 0.9467 - val_categorical_accuracy: 0.5715
# Epoch 82/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6272 - categorical_accuracy: 0.5718 - val_loss: 0.9244 - val_categorical_accuracy: 0.5721
# Epoch 83/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6270 - categorical_accuracy: 0.5725 - val_loss: 0.9847 - val_categorical_accuracy: 0.5726
# Epoch 84/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6252 - categorical_accuracy: 0.5731 - val_loss: 1.1036 - val_categorical_accuracy: 0.5728
# Epoch 85/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6246 - categorical_accuracy: 0.5732 - val_loss: 1.1011 - val_categorical_accuracy: 0.5730
# Epoch 86/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6231 - categorical_accuracy: 0.5734 - val_loss: 1.0379 - val_categorical_accuracy: 0.5734
# Epoch 87/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6220 - categorical_accuracy: 0.5737 - val_loss: 0.9594 - val_categorical_accuracy: 0.5739
# Epoch 88/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6209 - categorical_accuracy: 0.5742 - val_loss: 0.9025 - val_categorical_accuracy: 0.5744
# Epoch 89/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6198 - categorical_accuracy: 0.5749 - val_loss: 0.8628 - val_categorical_accuracy: 0.5751
# Epoch 90/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6199 - categorical_accuracy: 0.5756 - val_loss: 0.9833 - val_categorical_accuracy: 0.5756
# Epoch 91/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6202 - categorical_accuracy: 0.5761 - val_loss: 1.1471 - val_categorical_accuracy: 0.5758
# Epoch 92/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6202 - categorical_accuracy: 0.5761 - val_loss: 0.8660 - val_categorical_accuracy: 0.5763
# Epoch 93/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6163 - categorical_accuracy: 0.5767 - val_loss: 1.0247 - val_categorical_accuracy: 0.5767
# Epoch 94/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6152 - categorical_accuracy: 0.5770 - val_loss: 1.1321 - val_categorical_accuracy: 0.5769
# Epoch 95/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6145 - categorical_accuracy: 0.5770 - val_loss: 1.1253 - val_categorical_accuracy: 0.5770
# Epoch 96/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6132 - categorical_accuracy: 0.5773 - val_loss: 1.0360 - val_categorical_accuracy: 0.5773
# Epoch 97/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6121 - categorical_accuracy: 0.5775 - val_loss: 0.9483 - val_categorical_accuracy: 0.5777
# Epoch 98/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6111 - categorical_accuracy: 0.5781 - val_loss: 0.8964 - val_categorical_accuracy: 0.5782
# Epoch 99/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6102 - categorical_accuracy: 0.5786 - val_loss: 0.8673 - val_categorical_accuracy: 0.5788
# Epoch 100/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.6105 - categorical_accuracy: 0.5791 - val_loss: 1.0993 - val_categorical_accuracy: 0.5790

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
plt.plot(hist.history['categorical_accuracy'])
plt.plot(hist.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred=model.predict(X_val) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_val, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 0 34  0]
#  [ 0 34  0]
#  [ 0 29  6]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.3883495145631068

# %%
model.save_weights('/content/drive/MyDrive/inception_PECLESS')

# %%
model2 = create_model()

# %%
model2.load_weights('/content/drive/MyDrive/inception_PECLESS')

# %%
y_pred=model2.predict(X_val) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_val, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 0 34  0]
#  [ 0 34  0]
#  [ 0 29  6]]

# %%
X_train, X_test, y_train, y_test = dataset_stratified_split(split=0.20, dataset=images, labels=labels)

# %%
y_pred=model.predict(X_test) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_test, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 0  9  1]
#  [ 0 10  0]
#  [ 0 33  1]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.2037037037037037
