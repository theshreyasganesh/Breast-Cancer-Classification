# %%
import os 
os.environ['TF_KERAS'] = '1'
# %env TF_KERAS = 1
from tensorflow.keras.losses import CategoricalCrossentropy, BinaryCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy, BinaryAccuracy
from tensorflow.keras.optimizers import Adam
from tensorflow.python.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import random

from imutils import paths
import numpy as np
import pandas as pd
import skimage as sk
import skimage.transform
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
import json

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import accuracy_score, auc, classification_report, confusion_matrix, roc_curve
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
import ssl

from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Concatenate, Dense, Dropout, Flatten, Input
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
# Out:
# env: TF_KERAS=1

# %%
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf




def show_raw_image(img) -> None:
    """
    Displays a PIL image.
    :param img: the image in PIL format (before being converted to an array).
    :return: None.
    """
    img.show()




def create_label_encoder():
   
    return LabelEncoder()

# %%
# Constants
RANDOM_SEED = 111
VGG_IMG_SIZE = {
    "HEIGHT": 512,
    "WIDTH": 512
}
VGG_IMG_SIZE_LARGE = {
    "HEIGHT": 2048,
    "WIDTH": 2048
}
BATCH_SIZE = 2
EPOCH_1 = 150
EPOCH_2 = 50

# Variables set by command line arguments/flags
dataset = "mini-MIAS"   # The dataset to use.
model = "advanced"         # The model to use.
run_mode = "training"   # The type of running mode, either training or testing.
verbose_mode = False    # Boolean used to print additional logs for debugging purposes.
imagesize = "small"

# %%
def preprocess_image(image_path: str) -> np.ndarray:
 
    image = load_img(image_path,
                     color_mode="grayscale",
                     target_size=(VGG_IMG_SIZE['HEIGHT'], VGG_IMG_SIZE["WIDTH"]))
    image = img_to_array(image)
    image /= 255.0
    return image

def encode_labels(labels_list: np.ndarray, label_encoder) -> np.ndarray:
  
    labels = label_encoder.fit_transform(labels_list)
    if label_encoder.classes_.size == 2:
        return labels
    else:
        return to_categorical(labels)

def dataset_stratified_split(split: float, dataset: np.ndarray, labels: np.ndarray) -> \
        (np.ndarray, np.ndarray, np.ndarray, np.ndarray):
    
    train_X, test_X, train_Y, test_Y = train_test_split(dataset,
                                                        labels,
                                                        test_size=split,
                                                        stratify=labels,
                                                        random_state=RANDOM_SEED,
                                                        shuffle=True)
    return train_X, test_X, train_Y, test_Y


def random_rotation(image_array: np.ndarray):
    """
    Randomly rotate the image
    :param image_array: input image
    :return: randomly rotated image
    """
    random_degree = random.uniform(-20, 20)
    return sk.transform.rotate(image_array, random_degree)


def random_noise(image_array: np.ndarray):
    """
    Add random noise to image
    :param image_array: input image
    :return: image with added random noise
    """
    return sk.util.random_noise(image_array)


def horizontal_flip(image_array: np.ndarray):
    """
    Flip image
    :param image_array: input image
    :return: horizantally flipped image
    """
    return image_array[:, ::-1]




def create_individual_transform(image: np.array, transforms: dict):
    """
    Create transformation of an individual image
    :param image: input image
    :param transforms: the possible transforms to do on the image
    :return: transformed image
    """
    num_transformations_to_apply = random.randint(1, len(transforms))
    num_transforms = 0
    transformed_image = None
    while num_transforms <= num_transformations_to_apply:
        key = random.choice(list(transforms))
        transformed_image = transforms[key](image)
        num_transforms += 1

    return transformed_image


def get_class_balances(y_vals):
    """
    Count occurrences of each class.
    :param y_vals: labels
    :return: array count of each class
    """
    num_classes = len(y_vals[0])
    counts = np.zeros(num_classes)
    for y_val in y_vals:
        for i in range(num_classes):
            counts[i] += y_val[i]

    return (counts.tolist())



def import_minimias_dataset(data_dir: str, label_encoder) -> (np.ndarray, np.ndarray):
    """
    Import the dataset by pre-processing the images and encoding the labels.
    :param data_dir: Directory to the mini-MIAS images.
    :param label_encoder: The label encoder.
    :return: Two NumPy arrays, one for the processed images and one for the encoded labels.
    """
    # Initialise variables.
    images = list()
    labels = list()

    for image_path in list(paths.list_images(data_dir)):
        images.append(preprocess_image(image_path))
        labels.append(image_path.split(os.path.sep)[-2])  # Extract label from path.

    images = np.array(images, dtype="float32")  # Convert images to a batch.
    classes=labels
    labels = np.array(labels)

    # Encode labels.
    labels = encode_labels(labels, label_encoder)

    return images, labels, classes

# %%
def generate_image_transforms(images, labels):
    """
    oversample data by tranforming existing images
    :param images: input images
    :param labels: input labels
    :return: updated list of images and labels with extra transformed images and labels
    """
    images_with_transforms = images
    labels_with_transforms = labels

    available_transforms = {'rotate': random_rotation,
                            'noise': random_noise,
                            'horizontal_flip': horizontal_flip}

    class_balance = get_class_balances(labels)
    max_count = max(class_balance)
    to_add = [max_count - i for i in class_balance]

    for i in range(len(to_add)):
        if int(to_add[i]) == 0:
            continue
        label = np.zeros(len(to_add))
        label[i] = 1
        indices = [j for j, x in enumerate(labels) if np.array_equal(x, label)]
        indiv_class_images = [images[j] for j in indices]

        for k in range(int(to_add[i])):
            a = create_individual_transform(indiv_class_images[k % len(indiv_class_images)], available_transforms)
            transformed_image = create_individual_transform(indiv_class_images[k % len(indiv_class_images)],
                                                            available_transforms)
            transformed_image = transformed_image.reshape(1, VGG_IMG_SIZE['HEIGHT'],
                                                          VGG_IMG_SIZE['WIDTH'], 1)

            images_with_transforms = np.append(images_with_transforms, transformed_image, axis=0)
            transformed_label = label.reshape(1, len(label))
            labels_with_transforms = np.append(labels_with_transforms, transformed_label, axis=0)

    return images_with_transforms, labels_with_transforms

# %%
l_e = create_label_encoder()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
images, labels,classes = import_minimias_dataset(data_dir="/content/drive/MyDrive/ultrasound/images_u".format("mini-MIAS"),
                                                     label_encoder=l_e)

# %%
X_train, X_test, y_train, y_test = dataset_stratified_split(split=0.20, dataset=images, labels=labels)
X_train_rebalanced, y_train_rebalanced = generate_image_transforms(X_train, y_train)
X_train, X_val, y_train, y_val = dataset_stratified_split(split=0.25, dataset=X_train_rebalanced,
                                                                      labels=y_train_rebalanced)

# %%
import pandas as pd
classes=pd.DataFrame(classes)
classes[0].value_counts()
# Out:
# normal_cases       171
# benign_cases        51
# malignant_cases     48
# Name: 0, dtype: int64

# %%
classes[0].value_counts()[:20].plot(kind='barh')

# %%
ssl._create_default_https_context = ssl._create_unverified_context


def generate_vgg_model(classes_len: int):
    """
    Function to create a VGG19 model pre-trained with custom FC Layers.
    If the "advanced" command line argument is selected, adds an extra convolutional layer with extra filters to support
    larger images.
    :param classes_len: The number of classes (labels).
    :return: The VGG19 model.
    """
    img_input = Input(shape=(512, 512, 1))
    img_conc = Concatenate()([img_input, img_input, img_input])

    model_base = VGG19(include_top=False, weights='imagenet', input_tensor=img_conc)

    model = Sequential()
    model.add(model_base)

    if model == "advanced":
        model.add(Conv2D(512, (3, 3),
                         activation='relu',
                         padding='same'))
        model.add(Conv2D(512, (3, 3),
                         activation='relu',
                         padding='same'))
        model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(Flatten())

    model.add(Dense(units=512, activation='relu', name='Dense_Intermediate_1'))
    model.add(Dense(units=32, activation='relu', name='Dense_Intermediate_2'))

   
    if classes_len == 2:
        model.add(Dense(1, activation='sigmoid', name='Output'))
    else:
        model.add(Dense(classes_len, activation='softmax', name='Output'))

    if verbose_mode:
        print(model.summary())

    return model

# %%
model = generate_vgg_model(l_e.classes_.size)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step

# %%
    # Freeze VGG19 pre-trained layers.
   
model.layers[0].trainable = False

    # Train model with frozen layers (all training with early stopping dictated by loss in validation over 3 runs).


model.compile(optimizer='adam',loss=CategoricalCrossentropy(),metrics=[CategoricalAccuracy()])
hist = model.fit(X_train,
                 y_train,
                 validation_data=(X_val, y_val),

                 epochs=100,
                 batch_size=64,
                 )
# Out:
# Epoch 1/100
# 5/5 [==============================] - 88s 11s/step - loss: 25.2609 - categorical_accuracy: 0.2375 - val_loss: 35.5362 - val_categorical_accuracy: 0.2694
# Epoch 2/100
# 5/5 [==============================] - 12s 3s/step - loss: 22.6000 - categorical_accuracy: 0.2921 - val_loss: 7.3532 - val_categorical_accuracy: 0.3071
# Epoch 3/100
# 5/5 [==============================] - 12s 3s/step - loss: 6.8906 - categorical_accuracy: 0.3213 - val_loss: 5.6055 - val_categorical_accuracy: 0.3342
# Epoch 4/100
# 5/5 [==============================] - 12s 3s/step - loss: 3.5233 - categorical_accuracy: 0.3364 - val_loss: 3.9682 - val_categorical_accuracy: 0.3419
# Epoch 5/100
# 5/5 [==============================] - 12s 3s/step - loss: 2.1767 - categorical_accuracy: 0.3519 - val_loss: 1.5026 - val_categorical_accuracy: 0.3677
# Epoch 6/100
# 5/5 [==============================] - 12s 3s/step - loss: 1.0901 - categorical_accuracy: 0.3839 - val_loss: 2.5796 - val_categorical_accuracy: 0.4010
# Epoch 7/100
# 5/5 [==============================] - 12s 3s/step - loss: 1.2758 - categorical_accuracy: 0.4117 - val_loss: 2.5610 - val_categorical_accuracy: 0.4189
# Epoch 8/100
# 5/5 [==============================] - 12s 3s/step - loss: 1.0089 - categorical_accuracy: 0.4339 - val_loss: 1.3971 - val_categorical_accuracy: 0.4455
# Epoch 9/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.5117 - categorical_accuracy: 0.4648 - val_loss: 1.3549 - val_categorical_accuracy: 0.4768
# Epoch 10/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.4506 - categorical_accuracy: 0.4925 - val_loss: 1.1231 - val_categorical_accuracy: 0.5059
# Epoch 11/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.3243 - categorical_accuracy: 0.5215 - val_loss: 1.3619 - val_categorical_accuracy: 0.5349
# Epoch 12/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.2832 - categorical_accuracy: 0.5503 - val_loss: 1.1039 - val_categorical_accuracy: 0.5625
# Epoch 13/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.2212 - categorical_accuracy: 0.5759 - val_loss: 1.0196 - val_categorical_accuracy: 0.5865
# Epoch 14/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.1957 - categorical_accuracy: 0.5993 - val_loss: 1.0248 - val_categorical_accuracy: 0.6085
# Epoch 15/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.1763 - categorical_accuracy: 0.6192 - val_loss: 1.1667 - val_categorical_accuracy: 0.6280
# Epoch 16/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.1779 - categorical_accuracy: 0.6384 - val_loss: 0.9951 - val_categorical_accuracy: 0.6445
# Epoch 17/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.1614 - categorical_accuracy: 0.6531 - val_loss: 0.9920 - val_categorical_accuracy: 0.6593
# Epoch 18/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.1475 - categorical_accuracy: 0.6672 - val_loss: 1.2365 - val_categorical_accuracy: 0.6726
# Epoch 19/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.1484 - categorical_accuracy: 0.6802 - val_loss: 0.9733 - val_categorical_accuracy: 0.6846
# Epoch 20/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.1349 - categorical_accuracy: 0.6912 - val_loss: 1.0194 - val_categorical_accuracy: 0.6959
# Epoch 21/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.1164 - categorical_accuracy: 0.7019 - val_loss: 1.0447 - val_categorical_accuracy: 0.7061
# Epoch 22/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.1076 - categorical_accuracy: 0.7119 - val_loss: 1.0023 - val_categorical_accuracy: 0.7158
# Epoch 23/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.1006 - categorical_accuracy: 0.7212 - val_loss: 1.0408 - val_categorical_accuracy: 0.7249
# Epoch 24/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0967 - categorical_accuracy: 0.7297 - val_loss: 0.9880 - val_categorical_accuracy: 0.7328
# Epoch 25/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0908 - categorical_accuracy: 0.7372 - val_loss: 1.0377 - val_categorical_accuracy: 0.7405
# Epoch 26/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0866 - categorical_accuracy: 0.7449 - val_loss: 0.9741 - val_categorical_accuracy: 0.7476
# Epoch 27/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0901 - categorical_accuracy: 0.7514 - val_loss: 1.0385 - val_categorical_accuracy: 0.7540
# Epoch 28/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0801 - categorical_accuracy: 0.7578 - val_loss: 1.0137 - val_categorical_accuracy: 0.7602
# Epoch 29/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0752 - categorical_accuracy: 0.7635 - val_loss: 1.0079 - val_categorical_accuracy: 0.7659
# Epoch 30/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0703 - categorical_accuracy: 0.7692 - val_loss: 1.0117 - val_categorical_accuracy: 0.7713
# Epoch 31/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0686 - categorical_accuracy: 0.7744 - val_loss: 0.9930 - val_categorical_accuracy: 0.7764
# Epoch 32/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0666 - categorical_accuracy: 0.7794 - val_loss: 1.0560 - val_categorical_accuracy: 0.7812
# Epoch 33/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0647 - categorical_accuracy: 0.7840 - val_loss: 0.9837 - val_categorical_accuracy: 0.7857
# Epoch 34/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0610 - categorical_accuracy: 0.7883 - val_loss: 1.0627 - val_categorical_accuracy: 0.7899
# Epoch 35/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0590 - categorical_accuracy: 0.7924 - val_loss: 1.0050 - val_categorical_accuracy: 0.7937
# Epoch 36/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0535 - categorical_accuracy: 0.7961 - val_loss: 1.0352 - val_categorical_accuracy: 0.7976
# Epoch 37/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0515 - categorical_accuracy: 0.7999 - val_loss: 0.9946 - val_categorical_accuracy: 0.8011
# Epoch 38/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0493 - categorical_accuracy: 0.8033 - val_loss: 1.0229 - val_categorical_accuracy: 0.8045
# Epoch 39/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0464 - categorical_accuracy: 0.8066 - val_loss: 0.9865 - val_categorical_accuracy: 0.8077
# Epoch 40/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0456 - categorical_accuracy: 0.8097 - val_loss: 1.0401 - val_categorical_accuracy: 0.8108
# Epoch 41/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0432 - categorical_accuracy: 0.8127 - val_loss: 1.0009 - val_categorical_accuracy: 0.8137
# Epoch 42/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0423 - categorical_accuracy: 0.8155 - val_loss: 1.0208 - val_categorical_accuracy: 0.8164
# Epoch 43/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0398 - categorical_accuracy: 0.8182 - val_loss: 1.0153 - val_categorical_accuracy: 0.8191
# Epoch 44/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0377 - categorical_accuracy: 0.8207 - val_loss: 1.0253 - val_categorical_accuracy: 0.8216
# Epoch 45/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0371 - categorical_accuracy: 0.8232 - val_loss: 1.0095 - val_categorical_accuracy: 0.8240
# Epoch 46/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0351 - categorical_accuracy: 0.8255 - val_loss: 1.0220 - val_categorical_accuracy: 0.8263
# Epoch 47/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0343 - categorical_accuracy: 0.8278 - val_loss: 1.0142 - val_categorical_accuracy: 0.8286
# Epoch 48/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0332 - categorical_accuracy: 0.8300 - val_loss: 1.0313 - val_categorical_accuracy: 0.8307
# Epoch 49/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0316 - categorical_accuracy: 0.8321 - val_loss: 1.0076 - val_categorical_accuracy: 0.8327
# Epoch 50/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0305 - categorical_accuracy: 0.8341 - val_loss: 1.0270 - val_categorical_accuracy: 0.8347
# Epoch 51/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0296 - categorical_accuracy: 0.8360 - val_loss: 1.0098 - val_categorical_accuracy: 0.8365
# Epoch 52/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0284 - categorical_accuracy: 0.8378 - val_loss: 1.0265 - val_categorical_accuracy: 0.8384
# Epoch 53/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0274 - categorical_accuracy: 0.8396 - val_loss: 1.0181 - val_categorical_accuracy: 0.8401
# Epoch 54/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0277 - categorical_accuracy: 0.8413 - val_loss: 1.0223 - val_categorical_accuracy: 0.8418
# Epoch 55/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0257 - categorical_accuracy: 0.8429 - val_loss: 1.0398 - val_categorical_accuracy: 0.8434
# Epoch 56/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0248 - categorical_accuracy: 0.8445 - val_loss: 1.0076 - val_categorical_accuracy: 0.8449
# Epoch 57/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0245 - categorical_accuracy: 0.8460 - val_loss: 1.0398 - val_categorical_accuracy: 0.8464
# Epoch 58/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0232 - categorical_accuracy: 0.8474 - val_loss: 1.0217 - val_categorical_accuracy: 0.8479
# Epoch 59/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0224 - categorical_accuracy: 0.8489 - val_loss: 1.0074 - val_categorical_accuracy: 0.8493
# Epoch 60/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0219 - categorical_accuracy: 0.8503 - val_loss: 1.0361 - val_categorical_accuracy: 0.8507
# Epoch 61/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0214 - categorical_accuracy: 0.8516 - val_loss: 1.0099 - val_categorical_accuracy: 0.8520
# Epoch 62/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0205 - categorical_accuracy: 0.8529 - val_loss: 1.0324 - val_categorical_accuracy: 0.8533
# Epoch 63/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0200 - categorical_accuracy: 0.8542 - val_loss: 1.0209 - val_categorical_accuracy: 0.8546
# Epoch 64/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0193 - categorical_accuracy: 0.8554 - val_loss: 1.0135 - val_categorical_accuracy: 0.8558
# Epoch 65/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0186 - categorical_accuracy: 0.8566 - val_loss: 1.0414 - val_categorical_accuracy: 0.8570
# Epoch 66/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0182 - categorical_accuracy: 0.8578 - val_loss: 1.0192 - val_categorical_accuracy: 0.8581
# Epoch 67/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0175 - categorical_accuracy: 0.8589 - val_loss: 1.0327 - val_categorical_accuracy: 0.8592
# Epoch 68/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0173 - categorical_accuracy: 0.8600 - val_loss: 1.0334 - val_categorical_accuracy: 0.8603
# Epoch 69/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0166 - categorical_accuracy: 0.8610 - val_loss: 1.0340 - val_categorical_accuracy: 0.8613
# Epoch 70/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0163 - categorical_accuracy: 0.8621 - val_loss: 1.0153 - val_categorical_accuracy: 0.8623
# Epoch 71/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0157 - categorical_accuracy: 0.8630 - val_loss: 1.0500 - val_categorical_accuracy: 0.8633
# Epoch 72/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0154 - categorical_accuracy: 0.8640 - val_loss: 1.0258 - val_categorical_accuracy: 0.8642
# Epoch 73/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0152 - categorical_accuracy: 0.8649 - val_loss: 1.0336 - val_categorical_accuracy: 0.8652
# Epoch 74/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0144 - categorical_accuracy: 0.8658 - val_loss: 1.0327 - val_categorical_accuracy: 0.8661
# Epoch 75/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0143 - categorical_accuracy: 0.8667 - val_loss: 1.0246 - val_categorical_accuracy: 0.8669
# Epoch 76/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0139 - categorical_accuracy: 0.8676 - val_loss: 1.0542 - val_categorical_accuracy: 0.8678
# Epoch 77/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0136 - categorical_accuracy: 0.8684 - val_loss: 1.0261 - val_categorical_accuracy: 0.8686
# Epoch 78/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0131 - categorical_accuracy: 0.8692 - val_loss: 1.0423 - val_categorical_accuracy: 0.8694
# Epoch 79/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0127 - categorical_accuracy: 0.8700 - val_loss: 1.0398 - val_categorical_accuracy: 0.8702
# Epoch 80/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0124 - categorical_accuracy: 0.8708 - val_loss: 1.0343 - val_categorical_accuracy: 0.8710
# Epoch 81/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0121 - categorical_accuracy: 0.8716 - val_loss: 1.0392 - val_categorical_accuracy: 0.8718
# Epoch 82/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0118 - categorical_accuracy: 0.8723 - val_loss: 1.0380 - val_categorical_accuracy: 0.8725
# Epoch 83/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0116 - categorical_accuracy: 0.8730 - val_loss: 1.0386 - val_categorical_accuracy: 0.8732
# Epoch 84/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0113 - categorical_accuracy: 0.8737 - val_loss: 1.0376 - val_categorical_accuracy: 0.8739
# Epoch 85/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0111 - categorical_accuracy: 0.8744 - val_loss: 1.0547 - val_categorical_accuracy: 0.8746
# Epoch 86/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0108 - categorical_accuracy: 0.8751 - val_loss: 1.0421 - val_categorical_accuracy: 0.8752
# Epoch 87/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0105 - categorical_accuracy: 0.8758 - val_loss: 1.0399 - val_categorical_accuracy: 0.8759
# Epoch 88/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0103 - categorical_accuracy: 0.8764 - val_loss: 1.0455 - val_categorical_accuracy: 0.8765
# Epoch 89/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0101 - categorical_accuracy: 0.8770 - val_loss: 1.0458 - val_categorical_accuracy: 0.8772
# Epoch 90/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0100 - categorical_accuracy: 0.8776 - val_loss: 1.0546 - val_categorical_accuracy: 0.8778
# Epoch 91/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0096 - categorical_accuracy: 0.8782 - val_loss: 1.0364 - val_categorical_accuracy: 0.8784
# Epoch 92/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0095 - categorical_accuracy: 0.8788 - val_loss: 1.0449 - val_categorical_accuracy: 0.8789
# Epoch 93/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0093 - categorical_accuracy: 0.8794 - val_loss: 1.0486 - val_categorical_accuracy: 0.8795
# Epoch 94/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0090 - categorical_accuracy: 0.8800 - val_loss: 1.0426 - val_categorical_accuracy: 0.8801
# Epoch 95/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0088 - categorical_accuracy: 0.8805 - val_loss: 1.0579 - val_categorical_accuracy: 0.8806
# Epoch 96/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0087 - categorical_accuracy: 0.8811 - val_loss: 1.0467 - val_categorical_accuracy: 0.8812
# Epoch 97/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0085 - categorical_accuracy: 0.8816 - val_loss: 1.0476 - val_categorical_accuracy: 0.8817
# Epoch 98/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0083 - categorical_accuracy: 0.8821 - val_loss: 1.0549 - val_categorical_accuracy: 0.8822
# Epoch 99/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0081 - categorical_accuracy: 0.8826 - val_loss: 1.0558 - val_categorical_accuracy: 0.8827
# Epoch 100/100
# 5/5 [==============================] - 12s 3s/step - loss: 0.0080 - categorical_accuracy: 0.8831 - val_loss: 1.0493 - val_categorical_accuracy: 0.8832

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
plt.plot(hist.history['categorical_accuracy'])
plt.plot(hist.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred=model.predict(X_val) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_val, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[17 10  7]
#  [ 0 30  4]
#  [ 5  2 28]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7281553398058253

# %%
model.save_weights('/content/drive/MyDrive/VGG_PECLESS')

# %%
model2 = generate_vgg_model(l_e.classes_.size)

# %%
model2.load_weights('/content/gdrive/MyDrive/VGG_PECLESS')

# %%
y_pred=model2.predict(X_val) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_val, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[17 10  7]
#  [ 0 30  4]
#  [ 5  2 28]]

# %%
X_train, X_test, y_train, y_test = dataset_stratified_split(split=0.20, dataset=images, labels=labels)

# %%
y_pred=model.predict(X_test) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_test, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 3  0  7]
#  [ 2  2  6]
#  [ 3  7 24]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5370370370370371
