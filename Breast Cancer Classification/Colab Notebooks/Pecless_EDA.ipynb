# %%
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from matplotlib import pylab as pylab
import cv2
from google.colab import drive
import skimage
import os
from PIL import Image as im
import imageio

# %%
benign_images_directory ='/content/drive/MyDrive/Pec_removed_mini_mias/benign_cases'
malignant_images_directory ='/content/drive/MyDrive/Pec_removed_mini_mias/malignant_cases'
normal_images_directory ='/content/drive/MyDrive/Pec_removed_mini_mias/normal_cases'
dirs_li = [benign_images_directory,malignant_images_directory,normal_images_directory]
for images_directory in dirs_li:
  for root, directory, file in os.walk(images_directory):
    count = 0
    print('-----------------------------------')
    for f in file:
      count += 1
    print(count)
# Out:
# -----------------------------------
# 51
# -----------------------------------
# 48
# -----------------------------------
# 171
