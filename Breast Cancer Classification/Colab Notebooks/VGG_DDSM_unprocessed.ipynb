# %%
import os 
os.environ['TF_KERAS'] = '1'
# %env TF_KERAS = 1
from tensorflow.keras.losses import CategoricalCrossentropy, BinaryCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy, BinaryAccuracy
from tensorflow.keras.optimizers import Adam
from tensorflow.python.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import random

from imutils import paths
import numpy as np
import pandas as pd
import skimage as sk
import skimage.transform
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
import json

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import accuracy_score, auc, classification_report, confusion_matrix, roc_curve
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
import ssl

from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Concatenate, Dense, Dropout, Flatten, Input
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
# Out:
# env: TF_KERAS=1

# %%
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf




def show_raw_image(img) -> None:
    """
    Displays a PIL image.
    :param img: the image in PIL format (before being converted to an array).
    :return: None.
    """
    img.show()




def create_label_encoder():
   
    return LabelEncoder()

# %%
# Constants
RANDOM_SEED = 111
VGG_IMG_SIZE = {
    "HEIGHT": 512,
    "WIDTH": 512
}
VGG_IMG_SIZE_LARGE = {
    "HEIGHT": 2048,
    "WIDTH": 2048
}
BATCH_SIZE = 2
EPOCH_1 = 150
EPOCH_2 = 50

# Variables set by command line arguments/flags
dataset = "mini-MIAS"   # The dataset to use.
model = "advanced"         # The model to use.
run_mode = "training"   # The type of running mode, either training or testing.
verbose_mode = False    # Boolean used to print additional logs for debugging purposes.
imagesize = "small"

# %%
def preprocess_image(image_path: str) -> np.ndarray:
 
    image = load_img(image_path,
                     color_mode="grayscale",
                     target_size=(VGG_IMG_SIZE['HEIGHT'], VGG_IMG_SIZE["WIDTH"]))
    image = img_to_array(image)
    image /= 255.0
    return image

def encode_labels(labels_list: np.ndarray, label_encoder) -> np.ndarray:
  
    labels = label_encoder.fit_transform(labels_list)
    if label_encoder.classes_.size == 2:
        return labels
    else:
        return to_categorical(labels)

def dataset_stratified_split(split: float, dataset: np.ndarray, labels: np.ndarray) -> \
        (np.ndarray, np.ndarray, np.ndarray, np.ndarray):
    
    train_X, test_X, train_Y, test_Y = train_test_split(dataset,
                                                        labels,
                                                        test_size=split,
                                                        stratify=labels,
                                                        random_state=RANDOM_SEED,
                                                        shuffle=True)
    return train_X, test_X, train_Y, test_Y


def random_rotation(image_array: np.ndarray):
    """
    Randomly rotate the image
    :param image_array: input image
    :return: randomly rotated image
    """
    random_degree = random.uniform(-20, 20)
    return sk.transform.rotate(image_array, random_degree)


def random_noise(image_array: np.ndarray):
    """
    Add random noise to image
    :param image_array: input image
    :return: image with added random noise
    """
    return sk.util.random_noise(image_array)


def horizontal_flip(image_array: np.ndarray):
    """
    Flip image
    :param image_array: input image
    :return: horizantally flipped image
    """
    return image_array[:, ::-1]




def create_individual_transform(image: np.array, transforms: dict):
    """
    Create transformation of an individual image
    :param image: input image
    :param transforms: the possible transforms to do on the image
    :return: transformed image
    """
    num_transformations_to_apply = random.randint(1, len(transforms))
    num_transforms = 0
    transformed_image = None
    while num_transforms <= num_transformations_to_apply:
        key = random.choice(list(transforms))
        transformed_image = transforms[key](image)
        num_transforms += 1

    return transformed_image


def get_class_balances(y_vals):
    """
    Count occurrences of each class.
    :param y_vals: labels
    :return: array count of each class
    """
    num_classes = len(y_vals[0])
    counts = np.zeros(num_classes)
    for y_val in y_vals:
        for i in range(num_classes):
            counts[i] += y_val[i]

    return (counts.tolist())



def import_minimias_dataset(data_dir: str, label_encoder) -> (np.ndarray, np.ndarray):
    """
    Import the dataset by pre-processing the images and encoding the labels.
    :param data_dir: Directory to the mini-MIAS images.
    :param label_encoder: The label encoder.
    :return: Two NumPy arrays, one for the processed images and one for the encoded labels.
    """
    # Initialise variables.
    images = list()
    labels = list()

    for image_path in list(paths.list_images(data_dir)):
        images.append(preprocess_image(image_path))
        labels.append(image_path.split(os.path.sep)[-2])  # Extract label from path.

    images = np.array(images, dtype="float32")  # Convert images to a batch.
    classes=labels
    labels = np.array(labels)

    # Encode labels.
    labels = encode_labels(labels, label_encoder)

    return images, labels, classes

# %%
def generate_image_transforms(images, labels):
    """
    oversample data by tranforming existing images
    :param images: input images
    :param labels: input labels
    :return: updated list of images and labels with extra transformed images and labels
    """
    images_with_transforms = images
    labels_with_transforms = labels

    available_transforms = {'rotate': random_rotation,
                            'noise': random_noise,
                            'horizontal_flip': horizontal_flip}

    class_balance = get_class_balances(labels)
    max_count = max(class_balance)
    to_add = [max_count - i for i in class_balance]

    for i in range(len(to_add)):
        if int(to_add[i]) == 0:
            continue
        label = np.zeros(len(to_add))
        label[i] = 1
        indices = [j for j, x in enumerate(labels) if np.array_equal(x, label)]
        indiv_class_images = [images[j] for j in indices]

        for k in range(int(to_add[i])):
            a = create_individual_transform(indiv_class_images[k % len(indiv_class_images)], available_transforms)
            transformed_image = create_individual_transform(indiv_class_images[k % len(indiv_class_images)],
                                                            available_transforms)
            transformed_image = transformed_image.reshape(1, VGG_IMG_SIZE['HEIGHT'],
                                                          VGG_IMG_SIZE['WIDTH'], 1)

            images_with_transforms = np.append(images_with_transforms, transformed_image, axis=0)
            transformed_label = label.reshape(1, len(label))
            labels_with_transforms = np.append(labels_with_transforms, transformed_label, axis=0)

    return images_with_transforms, labels_with_transforms

# %%
l_e = create_label_encoder()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
images, labels,classes = import_minimias_dataset(data_dir="/content/drive/MyDrive/TRIAL".format("mini-MIAS"),
                                                     label_encoder=l_e)

# %%
X_train, X_test, y_train, y_test = dataset_stratified_split(split=0.30, dataset=images, labels=labels)
X_train_rebalanced, y_train_rebalanced = generate_image_transforms(X_train, y_train)
X_train, X_val, y_train, y_val = dataset_stratified_split(split=0.30, dataset=X_train_rebalanced,
                                                                      labels=y_train_rebalanced)

# %%
import pandas as pd
classes=pd.DataFrame(classes)
classes[0].value_counts()
# Out:
# benign_cases       301
# malignant_cases    301
# normal_cases       301
# Name: 0, dtype: int64

# %%
classes[0].value_counts()[:20].plot(kind='barh')

# %%
y_ = np.concatenate((y_train, y_val))

# %%
classes_2=[]
for arr in y_:
  if(np.array_equal(arr,np.array([1,0,0]))):
    classes_2.append('BENIGN')
  elif(np.array_equal(arr, np.array([0,1,0]))):
    classes_2.append('MALIGNANT')
  else:
    classes_2.append('NORMAL')

# %%
classes_2=pd.DataFrame(classes_2)
classes_2[0].value_counts()[:20].plot(kind='barh')

# %%
ssl._create_default_https_context = ssl._create_unverified_context


def generate_vgg_model(classes_len: int):
    """
    Function to create a VGG19 model pre-trained with custom FC Layers.
    If the "advanced" command line argument is selected, adds an extra convolutional layer with extra filters to support
    larger images.
    :param classes_len: The number of classes (labels).
    :return: The VGG19 model.
    """
    img_input = Input(shape=(512, 512, 1))
    img_conc = Concatenate()([img_input, img_input, img_input])

    model_base = VGG19(include_top=False, weights='imagenet', input_tensor=img_conc)

    model = Sequential()
    model.add(model_base)

    model.add(Conv2D(512, (3, 3),activation='relu',padding='same'))
    #model.add(Conv2D(512, (3, 3),activation='relu',padding='same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(Flatten())

    model.add(Dense(units=512, activation='relu', name='Dense_Intermediate_1'))
    model.add(Dense(units=32, activation='relu', name='Dense_Intermediate_2'))

   
    if classes_len == 2:
        model.add(Dense(1, activation='sigmoid', name='Output'))
    else:
        model.add(Dense(classes_len, activation='softmax', name='Output'))

    if verbose_mode:
        print(model.summary())

    return model

# %%
model = generate_vgg_model(3)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step

# %%
    # Freeze VGG19 pre-trained layers.
   
model.layers[0].trainable = False

    # Train model with frozen layers (all training with early stopping dictated by loss in validation over 3 runs).


model.compile(optimizer='adam',loss=CategoricalCrossentropy(),metrics=[CategoricalAccuracy()])
hist = model.fit(X_train,
                 y_train,
                 validation_data=(X_val, y_val),

                 epochs=100,
                 batch_size=64,
                 )
# Out:
# Epoch 1/100
# 7/7 [==============================] - 89s 14s/step - loss: 5.7288 - categorical_accuracy: 0.3048 - val_loss: 1.1168 - val_categorical_accuracy: 0.3292
# Epoch 2/100
# 7/7 [==============================] - 20s 3s/step - loss: 1.1214 - categorical_accuracy: 0.3313 - val_loss: 1.1086 - val_categorical_accuracy: 0.3392
# Epoch 3/100
# 7/7 [==============================] - 21s 3s/step - loss: 1.0891 - categorical_accuracy: 0.3484 - val_loss: 1.0532 - val_categorical_accuracy: 0.3567
# Epoch 4/100
# 7/7 [==============================] - 21s 3s/step - loss: 1.0571 - categorical_accuracy: 0.3673 - val_loss: 1.0129 - val_categorical_accuracy: 0.3797
# Epoch 5/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.9841 - categorical_accuracy: 0.3909 - val_loss: 0.9328 - val_categorical_accuracy: 0.3999
# Epoch 6/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.9083 - categorical_accuracy: 0.4100 - val_loss: 0.8619 - val_categorical_accuracy: 0.4202
# Epoch 7/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.8490 - categorical_accuracy: 0.4307 - val_loss: 0.8384 - val_categorical_accuracy: 0.4393
# Epoch 8/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.8054 - categorical_accuracy: 0.4493 - val_loss: 0.8683 - val_categorical_accuracy: 0.4591
# Epoch 9/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.7666 - categorical_accuracy: 0.4677 - val_loss: 0.8490 - val_categorical_accuracy: 0.4754
# Epoch 10/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.6976 - categorical_accuracy: 0.4849 - val_loss: 0.8864 - val_categorical_accuracy: 0.4908
# Epoch 11/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.6620 - categorical_accuracy: 0.4999 - val_loss: 0.8719 - val_categorical_accuracy: 0.5072
# Epoch 12/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.5933 - categorical_accuracy: 0.5174 - val_loss: 0.8676 - val_categorical_accuracy: 0.5238
# Epoch 13/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.5581 - categorical_accuracy: 0.5329 - val_loss: 0.8977 - val_categorical_accuracy: 0.5386
# Epoch 14/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.4808 - categorical_accuracy: 0.5471 - val_loss: 0.9088 - val_categorical_accuracy: 0.5538
# Epoch 15/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.4370 - categorical_accuracy: 0.5622 - val_loss: 1.0526 - val_categorical_accuracy: 0.5674
# Epoch 16/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.3997 - categorical_accuracy: 0.5745 - val_loss: 1.0130 - val_categorical_accuracy: 0.5794
# Epoch 17/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.3402 - categorical_accuracy: 0.5870 - val_loss: 1.0851 - val_categorical_accuracy: 0.5926
# Epoch 18/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.2929 - categorical_accuracy: 0.5998 - val_loss: 1.2171 - val_categorical_accuracy: 0.6049
# Epoch 19/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.2306 - categorical_accuracy: 0.6123 - val_loss: 1.3110 - val_categorical_accuracy: 0.6169
# Epoch 20/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.2254 - categorical_accuracy: 0.6233 - val_loss: 1.3884 - val_categorical_accuracy: 0.6269
# Epoch 21/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.2053 - categorical_accuracy: 0.6327 - val_loss: 1.4731 - val_categorical_accuracy: 0.6364
# Epoch 22/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.1682 - categorical_accuracy: 0.6421 - val_loss: 1.7039 - val_categorical_accuracy: 0.6456
# Epoch 23/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.1260 - categorical_accuracy: 0.6510 - val_loss: 1.5816 - val_categorical_accuracy: 0.6546
# Epoch 24/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.1027 - categorical_accuracy: 0.6598 - val_loss: 1.7223 - val_categorical_accuracy: 0.6631
# Epoch 25/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0904 - categorical_accuracy: 0.6680 - val_loss: 1.8028 - val_categorical_accuracy: 0.6712
# Epoch 26/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0757 - categorical_accuracy: 0.6757 - val_loss: 1.8743 - val_categorical_accuracy: 0.6786
# Epoch 27/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0647 - categorical_accuracy: 0.6831 - val_loss: 1.9792 - val_categorical_accuracy: 0.6859
# Epoch 28/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0514 - categorical_accuracy: 0.6901 - val_loss: 2.1137 - val_categorical_accuracy: 0.6926
# Epoch 29/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0444 - categorical_accuracy: 0.6964 - val_loss: 2.2139 - val_categorical_accuracy: 0.6987
# Epoch 30/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0367 - categorical_accuracy: 0.7024 - val_loss: 2.1437 - val_categorical_accuracy: 0.7047
# Epoch 31/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0220 - categorical_accuracy: 0.7082 - val_loss: 2.4239 - val_categorical_accuracy: 0.7102
# Epoch 32/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0187 - categorical_accuracy: 0.7136 - val_loss: 2.5537 - val_categorical_accuracy: 0.7158
# Epoch 33/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0177 - categorical_accuracy: 0.7191 - val_loss: 2.3647 - val_categorical_accuracy: 0.7211
# Epoch 34/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0209 - categorical_accuracy: 0.7241 - val_loss: 2.2973 - val_categorical_accuracy: 0.7259
# Epoch 35/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0163 - categorical_accuracy: 0.7287 - val_loss: 2.5867 - val_categorical_accuracy: 0.7303
# Epoch 36/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0102 - categorical_accuracy: 0.7329 - val_loss: 2.4804 - val_categorical_accuracy: 0.7344
# Epoch 37/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0071 - categorical_accuracy: 0.7370 - val_loss: 2.6483 - val_categorical_accuracy: 0.7384
# Epoch 38/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0051 - categorical_accuracy: 0.7407 - val_loss: 2.7026 - val_categorical_accuracy: 0.7420
# Epoch 39/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0038 - categorical_accuracy: 0.7443 - val_loss: 2.6980 - val_categorical_accuracy: 0.7455
# Epoch 40/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0030 - categorical_accuracy: 0.7477 - val_loss: 2.7776 - val_categorical_accuracy: 0.7488
# Epoch 41/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0026 - categorical_accuracy: 0.7508 - val_loss: 2.8184 - val_categorical_accuracy: 0.7519
# Epoch 42/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0023 - categorical_accuracy: 0.7539 - val_loss: 2.8344 - val_categorical_accuracy: 0.7549
# Epoch 43/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0019 - categorical_accuracy: 0.7568 - val_loss: 2.8635 - val_categorical_accuracy: 0.7577
# Epoch 44/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0018 - categorical_accuracy: 0.7596 - val_loss: 2.8438 - val_categorical_accuracy: 0.7605
# Epoch 45/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0016 - categorical_accuracy: 0.7623 - val_loss: 2.8902 - val_categorical_accuracy: 0.7632
# Epoch 46/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0015 - categorical_accuracy: 0.7649 - val_loss: 2.9205 - val_categorical_accuracy: 0.7657
# Epoch 47/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0014 - categorical_accuracy: 0.7673 - val_loss: 2.9326 - val_categorical_accuracy: 0.7681
# Epoch 48/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0013 - categorical_accuracy: 0.7697 - val_loss: 2.9456 - val_categorical_accuracy: 0.7704
# Epoch 49/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0012 - categorical_accuracy: 0.7719 - val_loss: 2.9714 - val_categorical_accuracy: 0.7726
# Epoch 50/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0012 - categorical_accuracy: 0.7740 - val_loss: 2.9727 - val_categorical_accuracy: 0.7747
# Epoch 51/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0011 - categorical_accuracy: 0.7761 - val_loss: 3.0076 - val_categorical_accuracy: 0.7767
# Epoch 52/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0010 - categorical_accuracy: 0.7781 - val_loss: 3.0083 - val_categorical_accuracy: 0.7787
# Epoch 53/100
# 7/7 [==============================] - 21s 3s/step - loss: 0.0010 - categorical_accuracy: 0.7800 - val_loss: 3.0225 - val_categorical_accuracy: 0.7806
# Epoch 54/100
# 7/7 [==============================] - 21s 3s/step - loss: 9.5754e-04 - categorical_accuracy: 0.7819 - val_loss: 3.0366 - val_categorical_accuracy: 0.7824
# Epoch 55/100
# 7/7 [==============================] - 21s 3s/step - loss: 9.1255e-04 - categorical_accuracy: 0.7836 - val_loss: 3.0693 - val_categorical_accuracy: 0.7841
# Epoch 56/100
# 7/7 [==============================] - 21s 3s/step - loss: 8.7591e-04 - categorical_accuracy: 0.7853 - val_loss: 3.0702 - val_categorical_accuracy: 0.7858
# Epoch 57/100
# 7/7 [==============================] - 21s 3s/step - loss: 8.3633e-04 - categorical_accuracy: 0.7870 - val_loss: 3.0955 - val_categorical_accuracy: 0.7874
# Epoch 58/100
# 7/7 [==============================] - 21s 3s/step - loss: 8.0425e-04 - categorical_accuracy: 0.7885 - val_loss: 3.1019 - val_categorical_accuracy: 0.7889
# Epoch 59/100
# 7/7 [==============================] - 21s 3s/step - loss: 7.5731e-04 - categorical_accuracy: 0.7899 - val_loss: 3.1070 - val_categorical_accuracy: 0.7904
# Epoch 60/100
# 7/7 [==============================] - 21s 3s/step - loss: 7.3833e-04 - categorical_accuracy: 0.7914 - val_loss: 3.1251 - val_categorical_accuracy: 0.7917
# Epoch 61/100
# 7/7 [==============================] - 21s 3s/step - loss: 7.0263e-04 - categorical_accuracy: 0.7928 - val_loss: 3.1442 - val_categorical_accuracy: 0.7931
# Epoch 62/100
# 7/7 [==============================] - 21s 3s/step - loss: 7.1057e-04 - categorical_accuracy: 0.7941 - val_loss: 3.1415 - val_categorical_accuracy: 0.7944
# Epoch 63/100
# 7/7 [==============================] - 21s 3s/step - loss: 6.5054e-04 - categorical_accuracy: 0.7954 - val_loss: 3.1608 - val_categorical_accuracy: 0.7957
# Epoch 64/100
# 7/7 [==============================] - 21s 3s/step - loss: 6.2517e-04 - categorical_accuracy: 0.7966 - val_loss: 3.1739 - val_categorical_accuracy: 0.7969
# Epoch 65/100
# 7/7 [==============================] - 21s 3s/step - loss: 6.1615e-04 - categorical_accuracy: 0.7979 - val_loss: 3.1733 - val_categorical_accuracy: 0.7982
# Epoch 66/100
# 7/7 [==============================] - 21s 3s/step - loss: 5.8173e-04 - categorical_accuracy: 0.7991 - val_loss: 3.2008 - val_categorical_accuracy: 0.7993
# Epoch 67/100
# 7/7 [==============================] - 21s 3s/step - loss: 5.7413e-04 - categorical_accuracy: 0.8002 - val_loss: 3.1995 - val_categorical_accuracy: 0.8005
# Epoch 68/100
# 7/7 [==============================] - 21s 3s/step - loss: 5.4254e-04 - categorical_accuracy: 0.8013 - val_loss: 3.2121 - val_categorical_accuracy: 0.8016
# Epoch 69/100
# 7/7 [==============================] - 21s 3s/step - loss: 5.1859e-04 - categorical_accuracy: 0.8024 - val_loss: 3.2152 - val_categorical_accuracy: 0.8027
# Epoch 70/100
# 7/7 [==============================] - 21s 3s/step - loss: 5.0374e-04 - categorical_accuracy: 0.8035 - val_loss: 3.2329 - val_categorical_accuracy: 0.8037
# Epoch 71/100
# 7/7 [==============================] - 21s 3s/step - loss: 4.9321e-04 - categorical_accuracy: 0.8045 - val_loss: 3.2435 - val_categorical_accuracy: 0.8047
# Epoch 72/100
# 7/7 [==============================] - 21s 3s/step - loss: 4.6793e-04 - categorical_accuracy: 0.8055 - val_loss: 3.2382 - val_categorical_accuracy: 0.8057
# Epoch 73/100
# 7/7 [==============================] - 21s 3s/step - loss: 4.6268e-04 - categorical_accuracy: 0.8064 - val_loss: 3.2560 - val_categorical_accuracy: 0.8066
# Epoch 74/100
# 7/7 [==============================] - 21s 3s/step - loss: 4.4148e-04 - categorical_accuracy: 0.8074 - val_loss: 3.2724 - val_categorical_accuracy: 0.8076
# Epoch 75/100
# 7/7 [==============================] - 21s 3s/step - loss: 4.2929e-04 - categorical_accuracy: 0.8083 - val_loss: 3.2850 - val_categorical_accuracy: 0.8085
# Epoch 76/100
# 7/7 [==============================] - 21s 3s/step - loss: 4.1653e-04 - categorical_accuracy: 0.8092 - val_loss: 3.2797 - val_categorical_accuracy: 0.8094
# Epoch 77/100
# 7/7 [==============================] - 21s 3s/step - loss: 3.9835e-04 - categorical_accuracy: 0.8101 - val_loss: 3.2976 - val_categorical_accuracy: 0.8102
# Epoch 78/100
# 7/7 [==============================] - 21s 3s/step - loss: 3.8722e-04 - categorical_accuracy: 0.8109 - val_loss: 3.3049 - val_categorical_accuracy: 0.8111
# Epoch 79/100
# 7/7 [==============================] - 21s 3s/step - loss: 3.7729e-04 - categorical_accuracy: 0.8117 - val_loss: 3.3114 - val_categorical_accuracy: 0.8119
# Epoch 80/100
# 7/7 [==============================] - 21s 3s/step - loss: 3.6811e-04 - categorical_accuracy: 0.8125 - val_loss: 3.3255 - val_categorical_accuracy: 0.8127
# Epoch 81/100
# 7/7 [==============================] - 21s 3s/step - loss: 3.6360e-04 - categorical_accuracy: 0.8133 - val_loss: 3.3203 - val_categorical_accuracy: 0.8135
# Epoch 82/100
# 7/7 [==============================] - 21s 3s/step - loss: 3.4662e-04 - categorical_accuracy: 0.8141 - val_loss: 3.3481 - val_categorical_accuracy: 0.8142
# Epoch 83/100
# 7/7 [==============================] - 21s 3s/step - loss: 3.3776e-04 - categorical_accuracy: 0.8148 - val_loss: 3.3496 - val_categorical_accuracy: 0.8150
# Epoch 84/100
# 7/7 [==============================] - 21s 3s/step - loss: 3.2622e-04 - categorical_accuracy: 0.8155 - val_loss: 3.3562 - val_categorical_accuracy: 0.8157
# Epoch 85/100
# 7/7 [==============================] - 21s 3s/step - loss: 3.1844e-04 - categorical_accuracy: 0.8163 - val_loss: 3.3548 - val_categorical_accuracy: 0.8164
# Epoch 86/100
# 7/7 [==============================] - 21s 3s/step - loss: 3.0619e-04 - categorical_accuracy: 0.8170 - val_loss: 3.3795 - val_categorical_accuracy: 0.8171
# Epoch 87/100
# 7/7 [==============================] - 21s 3s/step - loss: 3.0447e-04 - categorical_accuracy: 0.8176 - val_loss: 3.3914 - val_categorical_accuracy: 0.8177
# Epoch 88/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.9837e-04 - categorical_accuracy: 0.8183 - val_loss: 3.3813 - val_categorical_accuracy: 0.8184
# Epoch 89/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.8520e-04 - categorical_accuracy: 0.8190 - val_loss: 3.4049 - val_categorical_accuracy: 0.8191
# Epoch 90/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.7866e-04 - categorical_accuracy: 0.8196 - val_loss: 3.4103 - val_categorical_accuracy: 0.8197
# Epoch 91/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.6691e-04 - categorical_accuracy: 0.8202 - val_loss: 3.4091 - val_categorical_accuracy: 0.8203
# Epoch 92/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.6259e-04 - categorical_accuracy: 0.8208 - val_loss: 3.4195 - val_categorical_accuracy: 0.8209
# Epoch 93/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.5359e-04 - categorical_accuracy: 0.8214 - val_loss: 3.4219 - val_categorical_accuracy: 0.8215
# Epoch 94/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.5042e-04 - categorical_accuracy: 0.8220 - val_loss: 3.4296 - val_categorical_accuracy: 0.8220
# Epoch 95/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.4287e-04 - categorical_accuracy: 0.8225 - val_loss: 3.4446 - val_categorical_accuracy: 0.8226
# Epoch 96/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.3622e-04 - categorical_accuracy: 0.8231 - val_loss: 3.4435 - val_categorical_accuracy: 0.8232
# Epoch 97/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.3192e-04 - categorical_accuracy: 0.8236 - val_loss: 3.4555 - val_categorical_accuracy: 0.8237
# Epoch 98/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.2438e-04 - categorical_accuracy: 0.8242 - val_loss: 3.4586 - val_categorical_accuracy: 0.8242
# Epoch 99/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.1656e-04 - categorical_accuracy: 0.8247 - val_loss: 3.4711 - val_categorical_accuracy: 0.8247
# Epoch 100/100
# 7/7 [==============================] - 21s 3s/step - loss: 2.1298e-04 - categorical_accuracy: 0.8252 - val_loss: 3.4887 - val_categorical_accuracy: 0.8252

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
plt.plot(hist.history['categorical_accuracy'])
plt.plot(hist.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred=model.predict(X_val) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_val, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[23 20 20]
#  [24 37  2]
#  [ 6  7 51]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5842105263157895

# %%
model.save_weights('/content/drive/MyDrive/ddsm_vgg')

# %%
model2 = generate_vgg_model(l_e.classes_.size)

# %%
model.load_weights('/content/drive/MyDrive/inception_PECLESS')

# %%
y_pred=model2.predict(X_val) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_val, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[17 10  7]
#  [ 0 30  4]
#  [ 5  2 28]]

# %%
X_train, X_test, y_train, y_test = dataset_stratified_split(split=0.20, dataset=images, labels=labels)

# %%
y_pred=model.predict(X_test) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_test, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[25 20 15]
#  [13 33 14]
#  [ 7  5 49]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5911602209944752
