# %%
import os 
os.environ['TF_KERAS'] = '1'
# %env TF_KERAS = 1
from tensorflow.keras.losses import CategoricalCrossentropy, BinaryCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy, BinaryAccuracy
from tensorflow.keras.optimizers import Adam
from tensorflow.python.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import random

from imutils import paths
import numpy as np
import pandas as pd
import skimage as sk
import skimage.transform
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
import json

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import accuracy_score, auc, classification_report, confusion_matrix, roc_curve
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
import ssl

from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Concatenate, Dense, Dropout, Flatten, Input
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
# Out:
# env: TF_KERAS=1

# %%
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf




def show_raw_image(img) -> None:
    """
    Displays a PIL image.
    :param img: the image in PIL format (before being converted to an array).
    :return: None.
    """
    img.show()




def create_label_encoder():
   
    return LabelEncoder()

# %%
# Constants
RANDOM_SEED = 111
VGG_IMG_SIZE = {
    "HEIGHT": 512,
    "WIDTH": 512
}
VGG_IMG_SIZE_LARGE = {
    "HEIGHT": 2048,
    "WIDTH": 2048
}
BATCH_SIZE = 2
EPOCH_1 = 150
EPOCH_2 = 50

# Variables set by command line arguments/flags
dataset = "mini-MIAS"   # The dataset to use.
model = "advanced"         # The model to use.
run_mode = "training"   # The type of running mode, either training or testing.
verbose_mode = False    # Boolean used to print additional logs for debugging purposes.
imagesize = "small"

# %%
def preprocess_image(image_path: str) -> np.ndarray:
 
    image = load_img(image_path,
                     color_mode="grayscale",
                     target_size=(VGG_IMG_SIZE['HEIGHT'], VGG_IMG_SIZE["WIDTH"]))
    image = img_to_array(image)
    image /= 255.0
    return image

def encode_labels(labels_list: np.ndarray, label_encoder) -> np.ndarray:
  
    labels = label_encoder.fit_transform(labels_list)
    if label_encoder.classes_.size == 2:
        return labels
    else:
        return to_categorical(labels)

def dataset_stratified_split(split: float, dataset: np.ndarray, labels: np.ndarray) -> \
        (np.ndarray, np.ndarray, np.ndarray, np.ndarray):
    
    train_X, test_X, train_Y, test_Y = train_test_split(dataset,
                                                        labels,
                                                        test_size=split,
                                                        stratify=labels,
                                                        random_state=RANDOM_SEED,
                                                        shuffle=True)
    return train_X, test_X, train_Y, test_Y


def random_rotation(image_array: np.ndarray):
    """
    Randomly rotate the image
    :param image_array: input image
    :return: randomly rotated image
    """
    random_degree = random.uniform(-20, 20)
    return sk.transform.rotate(image_array, random_degree)


def random_noise(image_array: np.ndarray):
    """
    Add random noise to image
    :param image_array: input image
    :return: image with added random noise
    """
    return sk.util.random_noise(image_array)


def horizontal_flip(image_array: np.ndarray):
    """
    Flip image
    :param image_array: input image
    :return: horizantally flipped image
    """
    return image_array[:, ::-1]




def create_individual_transform(image: np.array, transforms: dict):
    """
    Create transformation of an individual image
    :param image: input image
    :param transforms: the possible transforms to do on the image
    :return: transformed image
    """
    num_transformations_to_apply = random.randint(1, len(transforms))
    num_transforms = 0
    transformed_image = None
    while num_transforms <= num_transformations_to_apply:
        key = random.choice(list(transforms))
        transformed_image = transforms[key](image)
        num_transforms += 1

    return transformed_image


def get_class_balances(y_vals):
    """
    Count occurrences of each class.
    :param y_vals: labels
    :return: array count of each class
    """
    num_classes = len(y_vals[0])
    counts = np.zeros(num_classes)
    for y_val in y_vals:
        for i in range(num_classes):
            counts[i] += y_val[i]

    return (counts.tolist())



def import_minimias_dataset(data_dir: str, label_encoder) -> (np.ndarray, np.ndarray):
    """
    Import the dataset by pre-processing the images and encoding the labels.
    :param data_dir: Directory to the mini-MIAS images.
    :param label_encoder: The label encoder.
    :return: Two NumPy arrays, one for the processed images and one for the encoded labels.
    """
    # Initialise variables.
    images = list()
    labels = list()

    for image_path in list(paths.list_images(data_dir)):
        images.append(preprocess_image(image_path))
        labels.append(image_path.split(os.path.sep)[-2])  # Extract label from path.

    images = np.array(images, dtype="float32")  # Convert images to a batch.
    classes=labels
    labels = np.array(labels)

    # Encode labels.
    labels = encode_labels(labels, label_encoder)

    return images, labels, classes

# %%
def generate_image_transforms(images, labels):
    """
    oversample data by tranforming existing images
    :param images: input images
    :param labels: input labels
    :return: updated list of images and labels with extra transformed images and labels
    """
    images_with_transforms = images
    labels_with_transforms = labels

    available_transforms = {'rotate': random_rotation,
                            'noise': random_noise,
                            'horizontal_flip': horizontal_flip}

    class_balance = get_class_balances(labels)
    max_count = max(class_balance)
    to_add = [max_count - i for i in class_balance]

    for i in range(len(to_add)):
        if int(to_add[i]) == 0:
            continue
        label = np.zeros(len(to_add))
        label[i] = 1
        indices = [j for j, x in enumerate(labels) if np.array_equal(x, label)]
        indiv_class_images = [images[j] for j in indices]

        for k in range(int(to_add[i])):
            a = create_individual_transform(indiv_class_images[k % len(indiv_class_images)], available_transforms)
            transformed_image = create_individual_transform(indiv_class_images[k % len(indiv_class_images)],
                                                            available_transforms)
            transformed_image = transformed_image.reshape(1, VGG_IMG_SIZE['HEIGHT'],
                                                          VGG_IMG_SIZE['WIDTH'], 1)

            images_with_transforms = np.append(images_with_transforms, transformed_image, axis=0)
            transformed_label = label.reshape(1, len(label))
            labels_with_transforms = np.append(labels_with_transforms, transformed_label, axis=0)

    return images_with_transforms, labels_with_transforms

# %%
l_e = create_label_encoder()

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
images, labels,classes = import_minimias_dataset(data_dir="/content/gdrive/MyDrive/images_".format("mini-MIAS"),label_encoder=l_e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-6462fd365b29> in <module>()
# ----> 1 images, labels,classes = import_minimias_dataset(data_dir="/content/gdrive/MyDrive/images_".format("mini-MIAS"),label_encoder=l_e)
#
# <ipython-input-4-1e7c7b4ee802> in import_minimias_dataset(data_dir, label_encoder)
#     112
#     113     # Encode labels.
# --> 114     labels = encode_labels(labels, label_encoder)
#     115
#     116     return images, labels, classes
#
# <ipython-input-4-1e7c7b4ee802> in encode_labels(labels_list, label_encoder)
#      15         return labels
#      16     else:
# ---> 17         return to_categorical(labels)
#      18
#      19 def dataset_stratified_split(split: float, dataset: np.ndarray, labels: np.ndarray) ->         (np.ndarray, np.ndarray, np.ndarray, np.ndarray):
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/np_utils.py in to_categorical(y, num_classes, dtype)
#      66   y = y.ravel()
#      67   if not num_classes:
# ---> 68     num_classes = np.max(y) + 1
#      69   n = y.shape[0]
#      70   categorical = np.zeros((n, num_classes), dtype=dtype)
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2753     """
#    2754     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
# -> 2755                           keepdims=keepdims, initial=initial, where=where)
#    2756
#    2757
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
import pandas as pd
classes=pd.DataFrame(classes)

# %%
classes[0].value_counts()
# Out:
# normal_cases       207
# benign_cases        63
# malignant_cases     51
# Name: 0, dtype: int64

# %%
classes[0].value_counts()[:20].plot(kind='barh')

# %%
X_train, X_test, y_train, y_test = dataset_stratified_split(split=0.20, dataset=images, labels=labels)

# %%
X_train_rebalanced, y_train_rebalanced = generate_image_transforms(X_train, y_train)
X_train, X_val, y_train, y_val = dataset_stratified_split(split=0.25, dataset=X_train_rebalanced,
                                                                      labels=y_train_rebalanced)

# %%
X_train.shape
# Out:
# (371, 512, 512, 1)

# %%
X_test.shape
# Out:
# (65, 512, 512, 1)

# %%
y_ = np.concatenate((y_train, y_val))

# %%
classes_2=[]
for arr in y_:
  if(np.array_equal(arr,np.array([1,0,0]))):
    classes_2.append('BENIGN')
  elif(np.array_equal(arr, np.array([0,1,0]))):
    classes_2.append('MALIGNANT')
  else:
    classes_2.append('NORMAL')

# %%
classes_2=pd.DataFrame(classes_2)
classes_2[0].value_counts()[:20].plot(kind='barh')

# %%
classes_2[0].value_counts()
# Out:
# MALIGNANT    165
# BENIGN       165
# NORMAL       165
# Name: 0, dtype: int64

# %%
def create_basic_cnn_model(num_classes: int):
    """
    Function to create a basic CNN.
    :param num_classes: The number of classes (labels).
    :return: A basic CNN model.
    """
    model = Sequential()

    # Convolutional + spooling layers
    model.add(Conv2D(64, (5, 5), input_shape=(512, 512, 1)))
    model.add(Conv2D(64, (5, 5), padding='same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(64, (5, 5), padding='same'))
    model.add(Conv2D(32, (5, 5), padding='same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Flatten())

    # Dropout
    model.add(Dropout(0.5, seed=RANDOM_SEED, name="Dropout_1"))

    # FC
    model.add(Dense(512, activation='relu', name='Dense_2'))

    # Output
    if num_classes == 2:
        model.add(Dense(1, activation='sigmoid', kernel_initializer="random_uniform", name='Output'))
    else:
        model.add(Dense(num_classes, activation='softmax', kernel_initializer="random_uniform", name='Output'))
        print(model.summary())

    return model

# %%
model =create_basic_cnn_model(l_e.classes_.size)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 508, 508, 64)      1664
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 508, 508, 64)      102464
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 254, 254, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 254, 254, 64)      102464
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 254, 254, 32)      51232
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 127, 127, 32)      0
# _________________________________________________________________
# module_wrapper (ModuleWrappe (None, 516128)            0
# _________________________________________________________________
# module_wrapper_1 (ModuleWrap (None, 516128)            0
# _________________________________________________________________
# module_wrapper_2 (ModuleWrap (None, 512)               264258048
# _________________________________________________________________
# module_wrapper_3 (ModuleWrap (None, 3)                 1539
# =================================================================
# Total params: 264,517,411
# Trainable params: 264,517,411
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
    # Train model with frozen layers (all training with early stopping dictated by loss in validation over 3 runs).


model.compile(optimizer='adam',loss=CategoricalCrossentropy(),metrics=[CategoricalAccuracy()])
hist = model.fit(X_train,
                 y_train,
                 validation_data=(X_val, y_val),

                 epochs=100,
                 batch_size=16,
                 )
# Out:
# Epoch 1/100
# 24/24 [==============================] - 45s 1s/step - loss: 34.7299 - categorical_accuracy: 0.4022 - val_loss: 84.6568 - val_categorical_accuracy: 0.3533
# Epoch 2/100
# 24/24 [==============================] - 23s 950ms/step - loss: 24.3934 - categorical_accuracy: 0.3532 - val_loss: 6.3145 - val_categorical_accuracy: 0.3584
# Epoch 3/100
# 24/24 [==============================] - 22s 925ms/step - loss: 9.8287 - categorical_accuracy: 0.3670 - val_loss: 4.8732 - val_categorical_accuracy: 0.3758
# Epoch 4/100
# 24/24 [==============================] - 22s 917ms/step - loss: 2.9018 - categorical_accuracy: 0.3924 - val_loss: 1.3379 - val_categorical_accuracy: 0.4036
# Epoch 5/100
# 24/24 [==============================] - 22s 927ms/step - loss: 1.1235 - categorical_accuracy: 0.4107 - val_loss: 1.0706 - val_categorical_accuracy: 0.4169
# Epoch 6/100
# 24/24 [==============================] - 22s 927ms/step - loss: 0.9977 - categorical_accuracy: 0.4188 - val_loss: 1.0624 - val_categorical_accuracy: 0.4236
# Epoch 7/100
# 24/24 [==============================] - 22s 923ms/step - loss: 0.9397 - categorical_accuracy: 0.4328 - val_loss: 1.0528 - val_categorical_accuracy: 0.4377
# Epoch 8/100
# 24/24 [==============================] - 22s 922ms/step - loss: 0.9528 - categorical_accuracy: 0.4416 - val_loss: 1.0557 - val_categorical_accuracy: 0.4436
# Epoch 9/100
# 24/24 [==============================] - 22s 924ms/step - loss: 0.8980 - categorical_accuracy: 0.4468 - val_loss: 1.1478 - val_categorical_accuracy: 0.4496
# Epoch 10/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.8781 - categorical_accuracy: 0.4550 - val_loss: 1.3057 - val_categorical_accuracy: 0.4572
# Epoch 11/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.8860 - categorical_accuracy: 0.4616 - val_loss: 1.0440 - val_categorical_accuracy: 0.4652
# Epoch 12/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.8465 - categorical_accuracy: 0.4705 - val_loss: 1.1793 - val_categorical_accuracy: 0.4738
# Epoch 13/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.9346 - categorical_accuracy: 0.4751 - val_loss: 1.0019 - val_categorical_accuracy: 0.4786
# Epoch 14/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.7973 - categorical_accuracy: 0.4831 - val_loss: 1.1025 - val_categorical_accuracy: 0.4867
# Epoch 15/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.7687 - categorical_accuracy: 0.4908 - val_loss: 1.0995 - val_categorical_accuracy: 0.4939
# Epoch 16/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.7487 - categorical_accuracy: 0.4989 - val_loss: 1.0643 - val_categorical_accuracy: 0.5017
# Epoch 17/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.7216 - categorical_accuracy: 0.5059 - val_loss: 1.1085 - val_categorical_accuracy: 0.5089
# Epoch 18/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.7305 - categorical_accuracy: 0.5123 - val_loss: 1.1152 - val_categorical_accuracy: 0.5143
# Epoch 19/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.6824 - categorical_accuracy: 0.5187 - val_loss: 1.3108 - val_categorical_accuracy: 0.5218
# Epoch 20/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.7533 - categorical_accuracy: 0.5234 - val_loss: 1.0013 - val_categorical_accuracy: 0.5252
# Epoch 21/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.6576 - categorical_accuracy: 0.5291 - val_loss: 1.1366 - val_categorical_accuracy: 0.5317
# Epoch 22/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.6134 - categorical_accuracy: 0.5348 - val_loss: 1.0875 - val_categorical_accuracy: 0.5374
# Epoch 23/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.5681 - categorical_accuracy: 0.5413 - val_loss: 1.2422 - val_categorical_accuracy: 0.5438
# Epoch 24/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.6785 - categorical_accuracy: 0.5455 - val_loss: 1.0508 - val_categorical_accuracy: 0.5475
# Epoch 25/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.5115 - categorical_accuracy: 0.5514 - val_loss: 1.1134 - val_categorical_accuracy: 0.5549
# Epoch 26/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.4597 - categorical_accuracy: 0.5592 - val_loss: 1.4012 - val_categorical_accuracy: 0.5623
# Epoch 27/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.5344 - categorical_accuracy: 0.5651 - val_loss: 1.3152 - val_categorical_accuracy: 0.5678
# Epoch 28/100
# 24/24 [==============================] - 22s 927ms/step - loss: 0.4471 - categorical_accuracy: 0.5711 - val_loss: 1.1510 - val_categorical_accuracy: 0.5735
# Epoch 29/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.4772 - categorical_accuracy: 0.5767 - val_loss: 1.3437 - val_categorical_accuracy: 0.5789
# Epoch 30/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.3865 - categorical_accuracy: 0.5823 - val_loss: 1.2232 - val_categorical_accuracy: 0.5854
# Epoch 31/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.3271 - categorical_accuracy: 0.5891 - val_loss: 1.3796 - val_categorical_accuracy: 0.5920
# Epoch 32/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.3387 - categorical_accuracy: 0.5952 - val_loss: 1.6492 - val_categorical_accuracy: 0.5975
# Epoch 33/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.4077 - categorical_accuracy: 0.6000 - val_loss: 1.1765 - val_categorical_accuracy: 0.6023
# Epoch 34/100
# 24/24 [==============================] - 22s 924ms/step - loss: 0.2919 - categorical_accuracy: 0.6057 - val_loss: 1.8209 - val_categorical_accuracy: 0.6082
# Epoch 35/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.2635 - categorical_accuracy: 0.6114 - val_loss: 1.5249 - val_categorical_accuracy: 0.6142
# Epoch 36/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.1930 - categorical_accuracy: 0.6176 - val_loss: 1.6119 - val_categorical_accuracy: 0.6204
# Epoch 37/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.2411 - categorical_accuracy: 0.6234 - val_loss: 1.3866 - val_categorical_accuracy: 0.6263
# Epoch 38/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.1903 - categorical_accuracy: 0.6296 - val_loss: 1.3476 - val_categorical_accuracy: 0.6318
# Epoch 39/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.1187 - categorical_accuracy: 0.6353 - val_loss: 1.5320 - val_categorical_accuracy: 0.6379
# Epoch 40/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.1040 - categorical_accuracy: 0.6411 - val_loss: 1.9427 - val_categorical_accuracy: 0.6437
# Epoch 41/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.1091 - categorical_accuracy: 0.6465 - val_loss: 1.7782 - val_categorical_accuracy: 0.6489
# Epoch 42/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.1355 - categorical_accuracy: 0.6516 - val_loss: 1.7808 - val_categorical_accuracy: 0.6539
# Epoch 43/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.1096 - categorical_accuracy: 0.6566 - val_loss: 2.1903 - val_categorical_accuracy: 0.6587
# Epoch 44/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.1621 - categorical_accuracy: 0.6610 - val_loss: 1.5643 - val_categorical_accuracy: 0.6628
# Epoch 45/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0725 - categorical_accuracy: 0.6655 - val_loss: 1.4520 - val_categorical_accuracy: 0.6678
# Epoch 46/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0472 - categorical_accuracy: 0.6705 - val_loss: 1.6562 - val_categorical_accuracy: 0.6728
# Epoch 47/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0261 - categorical_accuracy: 0.6754 - val_loss: 1.5622 - val_categorical_accuracy: 0.6775
# Epoch 48/100
# 24/24 [==============================] - 22s 924ms/step - loss: 0.0123 - categorical_accuracy: 0.6801 - val_loss: 1.8871 - val_categorical_accuracy: 0.6821
# Epoch 49/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0102 - categorical_accuracy: 0.6846 - val_loss: 1.8384 - val_categorical_accuracy: 0.6867
# Epoch 50/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0076 - categorical_accuracy: 0.6890 - val_loss: 2.0634 - val_categorical_accuracy: 0.6909
# Epoch 51/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0052 - categorical_accuracy: 0.6932 - val_loss: 2.0216 - val_categorical_accuracy: 0.6951
# Epoch 52/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0055 - categorical_accuracy: 0.6973 - val_loss: 2.0802 - val_categorical_accuracy: 0.6991
# Epoch 53/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0055 - categorical_accuracy: 0.7011 - val_loss: 2.1327 - val_categorical_accuracy: 0.7030
# Epoch 54/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0042 - categorical_accuracy: 0.7050 - val_loss: 2.1901 - val_categorical_accuracy: 0.7067
# Epoch 55/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0039 - categorical_accuracy: 0.7087 - val_loss: 2.3429 - val_categorical_accuracy: 0.7103
# Epoch 56/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0036 - categorical_accuracy: 0.7123 - val_loss: 2.2194 - val_categorical_accuracy: 0.7137
# Epoch 57/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0026 - categorical_accuracy: 0.7156 - val_loss: 2.3207 - val_categorical_accuracy: 0.7171
# Epoch 58/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0022 - categorical_accuracy: 0.7188 - val_loss: 2.3612 - val_categorical_accuracy: 0.7202
# Epoch 59/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0025 - categorical_accuracy: 0.7219 - val_loss: 2.4331 - val_categorical_accuracy: 0.7233
# Epoch 60/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0021 - categorical_accuracy: 0.7249 - val_loss: 2.4186 - val_categorical_accuracy: 0.7263
# Epoch 61/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0020 - categorical_accuracy: 0.7279 - val_loss: 2.4249 - val_categorical_accuracy: 0.7291
# Epoch 62/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0020 - categorical_accuracy: 0.7307 - val_loss: 2.4973 - val_categorical_accuracy: 0.7320
# Epoch 63/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0016 - categorical_accuracy: 0.7335 - val_loss: 2.4743 - val_categorical_accuracy: 0.7347
# Epoch 64/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0013 - categorical_accuracy: 0.7361 - val_loss: 2.5402 - val_categorical_accuracy: 0.7373
# Epoch 65/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0013 - categorical_accuracy: 0.7387 - val_loss: 2.5603 - val_categorical_accuracy: 0.7398
# Epoch 66/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0013 - categorical_accuracy: 0.7412 - val_loss: 2.5911 - val_categorical_accuracy: 0.7422
# Epoch 67/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0015 - categorical_accuracy: 0.7436 - val_loss: 2.6186 - val_categorical_accuracy: 0.7446
# Epoch 68/100
# 24/24 [==============================] - 22s 925ms/step - loss: 0.0011 - categorical_accuracy: 0.7459 - val_loss: 2.6425 - val_categorical_accuracy: 0.7470
# Epoch 69/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0011 - categorical_accuracy: 0.7482 - val_loss: 2.6955 - val_categorical_accuracy: 0.7492
# Epoch 70/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0011 - categorical_accuracy: 0.7504 - val_loss: 2.7275 - val_categorical_accuracy: 0.7514
# Epoch 71/100
# 24/24 [==============================] - 22s 926ms/step - loss: 0.0010 - categorical_accuracy: 0.7526 - val_loss: 2.7403 - val_categorical_accuracy: 0.7535
# Epoch 72/100
# 24/24 [==============================] - 22s 925ms/step - loss: 9.8354e-04 - categorical_accuracy: 0.7547 - val_loss: 2.7695 - val_categorical_accuracy: 0.7556
# Epoch 73/100
# 24/24 [==============================] - 22s 927ms/step - loss: 8.9305e-04 - categorical_accuracy: 0.7567 - val_loss: 2.7751 - val_categorical_accuracy: 0.7576
# Epoch 74/100
# 24/24 [==============================] - 22s 925ms/step - loss: 9.6758e-04 - categorical_accuracy: 0.7587 - val_loss: 2.7693 - val_categorical_accuracy: 0.7595
# Epoch 75/100
# 24/24 [==============================] - 22s 925ms/step - loss: 7.5657e-04 - categorical_accuracy: 0.7606 - val_loss: 2.7843 - val_categorical_accuracy: 0.7614
# Epoch 76/100
# 24/24 [==============================] - 22s 926ms/step - loss: 6.2904e-04 - categorical_accuracy: 0.7625 - val_loss: 2.7944 - val_categorical_accuracy: 0.7633
# Epoch 77/100
# 24/24 [==============================] - 22s 926ms/step - loss: 6.8476e-04 - categorical_accuracy: 0.7643 - val_loss: 2.8262 - val_categorical_accuracy: 0.7651
# Epoch 78/100
# 24/24 [==============================] - 22s 925ms/step - loss: 6.8553e-04 - categorical_accuracy: 0.7661 - val_loss: 2.8925 - val_categorical_accuracy: 0.7668
# Epoch 79/100
# 24/24 [==============================] - 22s 926ms/step - loss: 6.6920e-04 - categorical_accuracy: 0.7678 - val_loss: 2.8916 - val_categorical_accuracy: 0.7686
# Epoch 80/100
# 24/24 [==============================] - 22s 927ms/step - loss: 7.1619e-04 - categorical_accuracy: 0.7695 - val_loss: 2.8557 - val_categorical_accuracy: 0.7703
# Epoch 81/100
# 24/24 [==============================] - 22s 926ms/step - loss: 6.5203e-04 - categorical_accuracy: 0.7712 - val_loss: 2.8798 - val_categorical_accuracy: 0.7719
# Epoch 82/100
# 24/24 [==============================] - 22s 927ms/step - loss: 5.9421e-04 - categorical_accuracy: 0.7728 - val_loss: 2.8935 - val_categorical_accuracy: 0.7735
# Epoch 83/100
# 24/24 [==============================] - 22s 926ms/step - loss: 5.0786e-04 - categorical_accuracy: 0.7744 - val_loss: 2.9191 - val_categorical_accuracy: 0.7750
# Epoch 84/100
# 24/24 [==============================] - 22s 926ms/step - loss: 5.3383e-04 - categorical_accuracy: 0.7759 - val_loss: 2.9583 - val_categorical_accuracy: 0.7766
# Epoch 85/100
# 24/24 [==============================] - 22s 926ms/step - loss: 5.2407e-04 - categorical_accuracy: 0.7774 - val_loss: 2.9656 - val_categorical_accuracy: 0.7781
# Epoch 86/100
# 24/24 [==============================] - 22s 925ms/step - loss: 4.3852e-04 - categorical_accuracy: 0.7789 - val_loss: 2.9760 - val_categorical_accuracy: 0.7795
# Epoch 87/100
# 24/24 [==============================] - 22s 926ms/step - loss: 4.5409e-04 - categorical_accuracy: 0.7803 - val_loss: 3.0294 - val_categorical_accuracy: 0.7809
# Epoch 88/100
# 24/24 [==============================] - 22s 925ms/step - loss: 4.6006e-04 - categorical_accuracy: 0.7817 - val_loss: 3.0096 - val_categorical_accuracy: 0.7823
# Epoch 89/100
# 24/24 [==============================] - 22s 925ms/step - loss: 3.8480e-04 - categorical_accuracy: 0.7831 - val_loss: 3.0538 - val_categorical_accuracy: 0.7837
# Epoch 90/100
# 24/24 [==============================] - 22s 925ms/step - loss: 4.1615e-04 - categorical_accuracy: 0.7844 - val_loss: 3.0136 - val_categorical_accuracy: 0.7850
# Epoch 91/100
# 24/24 [==============================] - 22s 925ms/step - loss: 4.7413e-04 - categorical_accuracy: 0.7857 - val_loss: 3.0095 - val_categorical_accuracy: 0.7863
# Epoch 92/100
# 24/24 [==============================] - 22s 925ms/step - loss: 4.6874e-04 - categorical_accuracy: 0.7870 - val_loss: 3.0316 - val_categorical_accuracy: 0.7875
# Epoch 93/100
# 24/24 [==============================] - 22s 926ms/step - loss: 3.7326e-04 - categorical_accuracy: 0.7882 - val_loss: 3.0749 - val_categorical_accuracy: 0.7888
# Epoch 94/100
# 24/24 [==============================] - 22s 925ms/step - loss: 3.5223e-04 - categorical_accuracy: 0.7895 - val_loss: 3.1257 - val_categorical_accuracy: 0.7900
# Epoch 95/100
# 24/24 [==============================] - 22s 925ms/step - loss: 4.3401e-04 - categorical_accuracy: 0.7907 - val_loss: 3.1070 - val_categorical_accuracy: 0.7912
# Epoch 96/100
# 24/24 [==============================] - 22s 924ms/step - loss: 2.9074e-04 - categorical_accuracy: 0.7918 - val_loss: 3.1067 - val_categorical_accuracy: 0.7923
# Epoch 97/100
# 24/24 [==============================] - 22s 926ms/step - loss: 3.3210e-04 - categorical_accuracy: 0.7930 - val_loss: 3.1214 - val_categorical_accuracy: 0.7935
# Epoch 98/100
# 24/24 [==============================] - 22s 925ms/step - loss: 2.5170e-04 - categorical_accuracy: 0.7941 - val_loss: 3.1427 - val_categorical_accuracy: 0.7946
# Epoch 99/100
# 24/24 [==============================] - 22s 925ms/step - loss: 3.5270e-04 - categorical_accuracy: 0.7952 - val_loss: 3.1819 - val_categorical_accuracy: 0.7957
# Epoch 100/100
# 24/24 [==============================] - 22s 926ms/step - loss: 2.2232e-04 - categorical_accuracy: 0.7963 - val_loss: 3.1545 - val_categorical_accuracy: 0.7967

# %%
import matplotlib.pyplot as plt

# %%
 from sklearn.metrics import accuracy_score

# %%
plt.plot(hist.history['categorical_accuracy'])
plt.plot(hist.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred=model.predict(X_val) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_val, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[24  4 13]
#  [ 7 24 10]
#  [12  2 28]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6129032258064516

# %%
model.save_weights('/content/drive/MyDrive/CNN_PROCESSED')

# %%
model2 = create_basic_cnn_model(l_e.classes_.size)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 508, 508, 64)      1664
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 508, 508, 64)      102464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 254, 254, 64)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 254, 254, 64)      102464
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 254, 254, 32)      51232
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 127, 127, 32)      0
# _________________________________________________________________
# module_wrapper_4 (ModuleWrap (None, 516128)            0
# _________________________________________________________________
# module_wrapper_5 (ModuleWrap (None, 516128)            0
# _________________________________________________________________
# module_wrapper_6 (ModuleWrap (None, 512)               264258048
# _________________________________________________________________
# module_wrapper_7 (ModuleWrap (None, 3)                 1539
# =================================================================
# Total params: 264,517,411
# Trainable params: 264,517,411
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model2.load_weights('/content/drive/MyDrive/CNN_PROCESSED')
